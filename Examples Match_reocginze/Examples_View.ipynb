# %%
cd /home/monierashraf/Desktop/llm/Row_match_recognize && python3 trino_test_replication.py

# %% [markdown]
# # Example 1

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Simple test case to debug PREV function issue
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_1', '2020-05-14', 100),
    ('cust_1', '2020-05-16', 50),
    ('cust_1', '2020-05-17', 100),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])
df['order_date'] = pd.to_datetime(df['order_date'])

print("Test data:")
print(df)
print()

# Test simple query without PREV first
query_simple = """
SELECT customer_id, start_price, final_price, start_date, final_date
    FROM memory.default.orders
        MATCH_RECOGNIZE (
            PARTITION BY customer_id
            ORDER BY order_date
            MEASURES
                START.price AS start_price,
                LAST(DOWN.price) AS final_price,
                START.order_date AS start_date,
                LAST(DOWN.order_date) AS final_date
            ONE ROW PER MATCH
            AFTER MATCH SKIP PAST LAST ROW
            PATTERN (START DOWN+)
            DEFINE
                DOWN AS price < 150
            );
"""

print("Testing simple query without PREV:")
try:
    result = match_recognize(query_simple, df)
    print(result)
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
print()
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, start_price, final_price, start_date, final_date FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES START.price AS start_price, LAST(DOWN.price) AS final_price, START.order_date AS start_date, LAST(DOWN.order_date) AS final_date ONE ROW PER MATCH AFTER MATCH SKIP PAST LAST ROW PATTERN (START DOWN+) DEFINE DOWN AS price < 150 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=start_price, metadata={}), SelectItem(expression=final_price, metadata={}), SelectItem(expression=start_date, metadata={}), SelectItem(expression=final_date, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='START.price', alias='start_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(DOWN.price)', alias='final_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='START.order_date', alias='start_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(DOWN.order_date)', alias='final_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracting AFTER MATCH SKIP clause: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Extracted AFTER MATCH SKIP: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['START', 'DOWN+'], 'base_variables': ['START', 'DOWN']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: START DOWN+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='START DOWN+', metadata={'variables': ['START', 'DOWN+'], 'base_variables': ['START', 'DOWN']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='DOWN', condition='price < 150')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['START', 'DOWN+'], 'base_variables': ['START', 'DOWN']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: START DOWN+
# DEBUG:src.parser.match_recognize_extractor:Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'START.price': ['START']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(DOWN.price)': ['DOWN', 'DOWN']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'START.order_date': ['START']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(DOWN.order_date)': ['DOWN', 'DOWN']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price < 150': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'DOWN', 'START'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'DOWN', 'START'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'DOWN'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: START.price
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(DOWN.price)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: START.order_date
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(DOWN.order_date)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 4 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_price: START.price
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure final_price: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_date: START.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure final_date: LAST(DOWN.order_date)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'start_price': 'FINAL', 'final_price': 'FINAL', 'start_date': 'FINAL', 'final_date': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: START DOWN+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 0.00%, Memory used: 0.50 MB, Cache size: 1/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=3, measures=4, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: START)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: START
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was START)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition START: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable START
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Lt 150 = False (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: START)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: START
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was START)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition START: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable START
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 150 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 2 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-2, vars: ['START', 'DOWN']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1], 'DOWN': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Lt 150 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 2 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-3, vars: ['START', 'DOWN']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1], 'DOWN': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 150 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 2 at row 4
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-4, vars: ['START', 'DOWN']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 4, 'variables': {'START': [1], 'DOWN': [2, 3, 4]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 4, 'variables': {'START': [1], 'DOWN': [2, 3, 4]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.price, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting final_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.order_date, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.order_date), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting final_date to 2020-05-17 00:00:00 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 4
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'START': [1], 'DOWN': [2, 3, 4]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:start_price: 200
# INFO:row_match_recognize.src.matcher.matcher:final_price: 100
# INFO:row_match_recognize.src.matcher.matcher:start_date: 2020-05-12 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:final_date: 2020-05-17 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:4]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 5
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 5
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 5
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.045547 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'start_price': 200, 'final_price': 100, 'start_date': Timestamp('2020-05-12 00:00:00'), 'final_date': Timestamp('2020-05-17 00:00:00'), 'MATCH_NUMBER': 1, '_original_row_idx': 1, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.price, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for START
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting final_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.order_date, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for START
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-12 00:00:00 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3, 4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.order_date), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting final_date to 2020-05-17 00:00:00 from evaluator
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.012196540832519531, 'automata_build_time': 0.0019099712371826172, 'matching_time': 0.04752612113952637, 'result_processing_time': 0.010206460952758789, 'total_time': 0.07331275939941406, 'partition_count': 1, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 1, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 0.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 66.7% (2/3)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 0.50 MB
# Test data:
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_1 2020-05-14    100
# 3      cust_1 2020-05-16     50
# 4      cust_1 2020-05-17    100
#
# Testing simple query without PREV:
# Pattern value: 'START DOWN+'
# Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# Pattern value: 'START DOWN+'
# Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['START']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('START', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: START -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['START']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('START', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: START -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [('DOWN', 2, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: DOWN -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [('DOWN', 2, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: DOWN -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [('DOWN', 2, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: DOWN -> state 2 (alternation priority: N/A)
#   customer_id  start_price  final_price start_date final_date
# 0      cust_1          200          100 2020-05-12 2020-05-17

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT customer_id, start_date, end_date, bottom_price
FROM memory.default.orders
MATCH_RECOGNIZE (
PARTITION BY customer_id
ORDER BY order_date
MEASURES
A.order_date AS start_date,
C.order_date AS end_date,
C.price AS bottom_price
PATTERN (A B C)
DEFINE
B AS B.price < A.price,
C AS C.price < B.price
);


"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, start_date, end_date, bottom_price FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.order_date AS start_date, C.order_date AS end_date, C.price AS bottom_price PATTERN (A B C) DEFINE B AS B.price < A.price, C AS C.price < B.price );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=start_date, metadata={}), SelectItem(expression=end_date, metadata={}), SelectItem(expression=bottom_price, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.order_date', alias='start_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.order_date', alias='end_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.price', alias='bottom_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='B.price < A.price'), Define(variable='C', condition='C.price < B.price')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B C
# DEBUG:src.parser.match_recognize_extractor:Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.order_date': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'C.order_date': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'C.price': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'B.price < A.price': ['B', 'A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'C.price < B.price': ['C', 'B']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.price
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_date: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure end_date: C.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure bottom_price: C.price
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'start_date': 'FINAL', 'end_date': 'FINAL', 'bottom_price': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A B C
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=8, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0015s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6, 7] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [1, 8, 9] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [1, 9] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [6]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [1, 8] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [1, 8]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 3, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 4→4 states, 3→3 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 4 states, 3 transitions, 0.006s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0074s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 2
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=4, measures=3, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for A.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for A in ctx.variables: [0]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: A.price = 100 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Lt 100 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for A.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for A in ctx.variables: [1]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: A.price = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 50 (from row 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for B in ctx.variables: [2]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: B.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Lt 100 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=True, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 3 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-3, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 3 at row 4
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.order_date, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-16 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting end_date to 2020-05-16 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.price, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting bottom_price to 50 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [1], 'B': [2], 'C': [3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:start_date: 2020-05-12 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:end_date: 2020-05-16 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:bottom_price: 50
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=4
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 4, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 4
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.056497 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'start_date': Timestamp('2020-05-12 00:00:00'), 'end_date': Timestamp('2020-05-16 00:00:00'), 'bottom_price': 50, 'MATCH_NUMBER': 1, '_original_row_idx': 1, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 4 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for A.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for A in ctx.variables: [0]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: A.price = 8 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), right=8 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 4 Lt 8 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 6 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for B in ctx.variables: [1]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: B.price = 4 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=4 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Lt 4 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 2 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 6 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - cross-reference for A.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Looking for A in ctx.variables: [1]
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Cross-reference value: A.price = 4 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=4 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Lt 4 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price < A.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < B.price
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C', 'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=True
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.034662 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-12 00:00:00 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.order_date, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-16 00:00:00 at index 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-16 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_date to 2020-05-16 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.price, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 50 at index 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting bottom_price to 50 from evaluator
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.012938499450683594, 'automata_build_time': 0.022083520889282227, 'matching_time': 0.09404611587524414, 'result_processing_time': 0.010511636734008789, 'total_time': 0.1411426067352295, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 2, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 1.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 50.0% (2/4)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 1.00 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: 'A B C'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# Pattern value: 'A B C'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG: DFA metadata keys: ['pattern_variables', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('B', 2, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: _find_single_match called with start_idx=4
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('B', 2, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [('A', 1, False)], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'prerequisite' with 1 transitions
# DEBUG: Selected prerequisite transition: A -> state 1 (alternation priority: N/A)
#   customer_id start_date   end_date  bottom_price
# 0      cust_1 2020-05-12 2020-05-16            50

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT
customer_id,
start_price,
last_b_price AS peak_price,
last_c_price AS bottom_price,
last_d_price AS end_price,
start_date,
end_date
FROM memory.default.orders
MATCH_RECOGNIZE (
PARTITION BY customer_id
ORDER BY order_date
MEASURES
A.price AS start_price,
LAST(B.price) AS last_b_price,
LAST(C.price) AS last_c_price,
LAST(D.price) AS last_d_price,
A.order_date AS start_date,
LAST(D.order_date) AS end_date
PATTERN (A B+ C+ D+)
DEFINE
B AS B.price > PREV(price),
C AS C.price < PREV(price),
D AS D.price > PREV(price)
);

"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, start_price, last_b_price AS peak_price, last_c_price AS bottom_price, last_d_price AS end_price, start_date, end_date FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.price AS start_price, LAST(B.price) AS last_b_price, LAST(C.price) AS last_c_price, LAST(D.price) AS last_d_price, A.order_date AS start_date, LAST(D.order_date) AS end_date PATTERN (A B+ C+ D+) DEFINE B AS B.price > PREV(price), C AS C.price < PREV(price), D AS D.price > PREV(price) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=start_price, metadata={}), SelectItem(expression=last_b_price, alias=peak_price, metadata={}), SelectItem(expression=last_c_price, alias=bottom_price, metadata={}), SelectItem(expression=last_d_price, alias=end_price, metadata={}), SelectItem(expression=start_date, metadata={}), SelectItem(expression=end_date, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.price', alias='start_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.price)', alias='last_b_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(C.price)', alias='last_c_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(D.price)', alias='last_d_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='A.order_date', alias='start_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(D.order_date)', alias='end_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+ D+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C+ D+', metadata={'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='B.price > PREV(price)'), Define(variable='C', condition='C.price < PREV(price)'), Define(variable='D', condition='D.price > PREV(price)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+ D+
# DEBUG:src.parser.match_recognize_extractor:Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(B.price)': ['B', 'B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(C.price)': ['C', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(D.price)': ['D', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.order_date': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(D.order_date)': ['D', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'B.price > PREV(price)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'C.price < PREV(price)': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'D.price > PREV(price)': ['D']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'A', 'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(B.price)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(C.price)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(D.price)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(D.order_date)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 6 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_price: A.price
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_b_price: LAST(B.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_c_price: LAST(C.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_d_price: LAST(D.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_date: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure end_date: LAST(D.order_date)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'start_price': 'FINAL', 'last_b_price': 'FINAL', 'last_c_price': 'FINAL', 'last_d_price': 'FINAL', 'start_date': 'FINAL', 'end_date': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A B+ C+ D+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='D', target=14, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [5, 6, 8, 9, 11] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [5, 7] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8, 9, 11] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [9, 10, 12, 13, 15] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [9, 11] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13, 15] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [1, 13, 14, 16, 17] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [13, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [1, 16, 17] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [1, 17] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='D', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='D', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='D', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='D', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [6]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [10]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 3, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 3, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [1, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [1, 14]: accept=True, variables={'D'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 4, variable='D'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [1, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 4, variable='D'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 5→5 states, 7→7 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 5 states, 7 transitions, 0.011s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0139s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 3
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=5, measures=6, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 200 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 50 (from row 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Lt 100 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: D
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=D, col_name=price, is_define_mode=True, current_var=D
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for D.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: D.price = 50 (from row 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Gt 100 = False (evaluating for var=D)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was D)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=4, ctx.variables={'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 100 (from row 4)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 50 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: D
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=D, col_name=price, is_define_mode=True, current_var=D
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=4, ctx.variables={'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for D.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: D.price = 100 (from row 4)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 50 = True (evaluating for var=D)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was D)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition D: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable D
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 4 at row 4
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-4, vars: ['A', 'B', 'C', 'D']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 4, 'variables': {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}, 'state': 4, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 4, 'variables': {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}, 'state': 4, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_b_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_c_price to 50 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_d_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.order_date), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting end_date to 2020-05-17 00:00:00 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 4
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:start_price: 100
# INFO:row_match_recognize.src.matcher.matcher:last_b_price: 200
# INFO:row_match_recognize.src.matcher.matcher:last_c_price: 50
# INFO:row_match_recognize.src.matcher.matcher:last_d_price: 100
# INFO:row_match_recognize.src.matcher.matcher:start_date: 2020-05-11 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:end_date: 2020-05-17 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:4]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 5
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 5
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 5
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.061971 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'start_price': 100, 'last_b_price': 200, 'last_c_price': 50, 'last_d_price': 100, 'start_date': Timestamp('2020-05-11 00:00:00'), 'end_date': Timestamp('2020-05-17 00:00:00'), 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# ...
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.035807 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_b_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_c_price to 50 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_d_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-11 00:00:00 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.order_date), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_date to 2020-05-17 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:Applied column aliases: {'last_b_price': 'peak_price', 'last_c_price': 'bottom_price', 'last_d_price': 'end_price'}
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.020690441131591797, 'automata_build_time': 0.03801870346069336, 'matching_time': 0.10236406326293945, 'result_processing_time': 0.017094135284423828, 'total_time': 0.18030285835266113, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 3, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 1.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 40.0% (2/5)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 1.50 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: 'A B+ C+ D+'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# Pattern value: 'A B+ C+ D+'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 3, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 3, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['D']
# DEBUG: Categorized transitions: {'accepting': [('D', 4, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: D -> state 4 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
#   customer_id  start_price  peak_price  bottom_price  end_price start_date  \
# 0      cust_1          100         200            50        100 2020-05-11
#
#     end_date
# 0 2020-05-17

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT
customer_id,
a_date AS first_date,
b_date AS second_date,
a_price AS first_price,
b_price AS second_price
FROM memory.default.orders
MATCH_RECOGNIZE (
PARTITION BY customer_id
ORDER BY order_date
MEASURES
A.order_date AS a_date,
B.order_date AS b_date,
A.price AS a_price,
B.price AS b_price
PATTERN (^A B)
DEFINE
A AS price < 150,
B AS price > PREV(price)
);

"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, a_date AS first_date, b_date AS second_date, a_price AS first_price, b_price AS second_price FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.order_date AS a_date, B.order_date AS b_date, A.price AS a_price, B.price AS b_price PATTERN (^A B) DEFINE A AS price < 150, B AS price > PREV(price) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=a_date, alias=first_date, metadata={}), SelectItem(expression=b_date, alias=second_date, metadata={}), SelectItem(expression=a_price, alias=first_price, metadata={}), SelectItem(expression=b_price, alias=second_price, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.order_date', alias='a_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.order_date', alias='b_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='A.price', alias='a_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.price', alias='b_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A B
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='^A B', metadata={'variables': ['A', 'B'], 'base_variables': ['A', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='price < 150'), Define(variable='B', condition='price > PREV(price)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B'], 'base_variables': ['A', 'B']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A B
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.order_date': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'B.order_date': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'B.price': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price < 150': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price > PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.price
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 4 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure a_date: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure b_date: B.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure a_price: A.price
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure b_price: B.price
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'a_date': 'FINAL', 'b_date': 'FINAL', 'a_price': 'FINAL', 'b_price': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: ^A B
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=7, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 4] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 4] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 4] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0012s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [1, 7, 8] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [1, 8] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=True
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [5]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [1, 7] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [1, 7]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='B'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 3→3 states, 2→2 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 3 states, 2 transitions, 0.004s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0051s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 4
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=3, measures=4, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 150 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A', 'B']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 2 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0], 'B': [1]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 1, 'variables': {'A': [0], 'B': [1]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.order_date, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.price, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_price to 200 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:a_date: 2020-05-11 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:b_date: 2020-05-12 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:a_price: 100
# INFO:row_match_recognize.src.matcher.matcher:b_price: 200
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=4
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 4, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=4 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 4
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.046261 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'a_date': Timestamp('2020-05-11 00:00:00'), 'b_date': Timestamp('2020-05-12 00:00:00'), 'a_price': 100, 'b_price': 200, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 8
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=8 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=8 (<class 'int'>), right=150 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 8 Lt 150 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 8
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), right=8 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 4 Gt 8 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price < 150
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.024788 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-11 00:00:00 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.order_date, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-12 00:00:00 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.price, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_price to 200 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:Applied column aliases: {'a_date': 'first_date', 'b_date': 'second_date', 'a_price': 'first_price', 'b_price': 'second_price'}
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.01659870147705078, 'automata_build_time': 0.018363475799560547, 'matching_time': 0.07597541809082031, 'result_processing_time': 0.013079643249511719, 'total_time': 0.12581706047058105, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 4, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 2.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (2/6)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 2.00 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: '^A B'
# Pattern value: '^A B'
# DEBUG: DFA metadata keys: ['has_start_anchor', 'pattern_variables', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 2, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=4
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
#   customer_id first_date second_date  first_price  second_price
# 0      cust_1 2020-05-11  2020-05-12          100           200

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT
customer_id,
run_start,
run_end
FROM memory.default.orders
MATCH_RECOGNIZE (
PARTITION BY customer_id
ORDER BY order_date
MEASURES
A.order_date AS run_start,
LAST(B.order_date) AS run_end
PATTERN (A B+)
DEFINE
A AS price >= 100,
B AS price > PREV(price)
);

"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, run_start, run_end FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.order_date AS run_start, LAST(B.order_date) AS run_end PATTERN (A B+) DEFINE A AS price >= 100, B AS price > PREV(price) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=run_start, metadata={}), SelectItem(expression=run_end, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.order_date', alias='run_start', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.order_date)', alias='run_end', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+', metadata={'variables': ['A', 'B+'], 'base_variables': ['A', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='price >= 100'), Define(variable='B', condition='price > PREV(price)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.order_date': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(B.order_date)': ['B', 'B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price >= 100': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price > PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(B.order_date)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure run_start: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure run_end: LAST(B.order_date)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'run_start': 'FINAL', 'run_end': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A B+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [1, 5, 6, 8, 9] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [5, 7] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [1, 8, 9] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [1, 9] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [1, 6] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [1, 6]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [1, 6] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 2, variable='B'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 3→3 states, 3→3 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 3 states, 3 transitions, 0.004s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0050s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 5
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=3, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 GtE 100 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A', 'B']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 200 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 2 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0], 'B': [1]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 1, 'variables': {'A': [0], 'B': [1]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting run_start to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.order_date), current_idx=1, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting run_end to 2020-05-12 00:00:00 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:run_start: 2020-05-11 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:run_end: 2020-05-12 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 GtE 100 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Gt 100 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 GtE 100 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 3
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=4
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 4, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 GtE 100 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 4
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.053512 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'run_start': Timestamp('2020-05-11 00:00:00'), 'run_end': Timestamp('2020-05-12 00:00:00'), 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 8
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=8 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=8 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 8 GtE 100 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 4 GtE 100 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price >= 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=GtE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 GtE 100 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.026799 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-11 00:00:00 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting run_start to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.order_date), current_idx=1, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting run_end to 2020-05-12 00:00:00 from evaluator
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.014144659042358398, 'automata_build_time': 0.015813589096069336, 'matching_time': 0.08386349678039551, 'result_processing_time': 0.007747650146484375, 'total_time': 0.12412738800048828, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 5, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 2.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 28.6% (2/7)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 2.50 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: 'A B+'
# Pattern value: 'A B+'
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 2, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=4
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
#   customer_id  run_start    run_end
# 0      cust_1 2020-05-11 2020-05-12

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT
customer_id,
first_a_date AS a_date,
first_b_date AS b_date,
first_c_date AS c_date
FROM memory.default.orders
MATCH_RECOGNIZE (
PARTITION BY customer_id
ORDER BY order_date
MEASURES
A.order_date AS first_a_date,
B.order_date AS first_b_date,
C.order_date AS first_c_date
PATTERN (PERMUTE(A, B, C))
DEFINE
A AS price = 100,
B AS price = 50,
C AS price = 200
);

"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, first_a_date AS a_date, first_b_date AS b_date, first_c_date AS c_date FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.order_date AS first_a_date, B.order_date AS first_b_date, C.order_date AS first_c_date PATTERN (PERMUTE(A, B, C)) DEFINE A AS price = 100, B AS price = 50, C AS price = 200 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=first_a_date, alias=a_date, metadata={}), SelectItem(expression=first_b_date, alias=b_date, metadata={}), SelectItem(expression=first_c_date, alias=c_date, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.order_date', alias='first_a_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.order_date', alias='first_b_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.order_date', alias='first_c_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='price = 100'), Define(variable='B', condition='price = 50'), Define(variable='C', condition='price = 200')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.order_date
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.order_date
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure first_a_date: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure first_b_date: B.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure first_c_date: C.order_date
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'first_a_date': 'FINAL', 'first_b_date': 'FINAL', 'first_c_date': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# DEBUG: _process_permute called with variables: ['A', 'B', 'C']
# DEBUG: Token metadata: {'variables': ['A', 'B', 'C'], 'variable_count': 3, 'original': 'PERMUTE(A, B, C)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=13, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=17, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=20, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=22, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=24, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=27, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=29, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=31, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=34, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=36, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=38, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=41, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=43, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=45, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=48, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=50, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=52, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0009s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 15)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 14)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 13)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4, 47] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7, 8] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 10] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 4, 11, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [15] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16, 17] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [17] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 4, 18, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [19] = [19, 20] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [20] = [20] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [21] = [21, 22] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [22] = [22] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23, 24] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [24] = [24] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 4, 25, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [26] = [26, 27] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [27] = [27] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28] = [28, 29] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0024s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [29] = [29] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30, 31] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [31] = [31] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 4, 32, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [33] = [33, 34] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [34] = [34] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [35] = [35, 36] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [36] = [36] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37, 38] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [38] = [38] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 4, 39, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [40] = [40, 41] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [41] = [41] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42] = [42, 43] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [43] = [43] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44, 45] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [45] = [45] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 4, 46, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [47] = [1, 47] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=9, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=18, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=23, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=25, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=30, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=32, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=37, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=39, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=44, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=46, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [35, 42]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [7, 14]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [21, 28]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [44]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 4, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 5 from NFA states [37]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 5, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 6 from NFA states [16]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 6, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 7 from NFA states [9]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 7, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 8 from NFA states [30]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 8, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 9 from NFA states [23]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 9, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 46] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 10 from NFA states [1, 46]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 10, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 39] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 11 from NFA states [1, 39]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 5: added transition to 11, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 12 from NFA states [1, 18]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 6: added transition to 12, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 13 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 7: added transition to 13, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 32] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 14 from NFA states [1, 32]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 8: added transition to 14, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 25] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 15 from NFA states [1, 25]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 9: added transition to 15, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:Merging 3 equivalent state pairs
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 16→13 states, 15→15 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 16 states, 15 transitions, 0.017s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0185s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 6
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=3, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price = 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price = 50
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: price = 200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price = 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price = 50
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: price = 200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 200 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 200 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 100 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Eq 200 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'C': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 6 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price = 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price = 50
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: price = 200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: price = 100
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price = 50
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: price = 200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Eq 200 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Eq
# ...
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: price = 50
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: price = 200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 200 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 200 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 100 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 100 = False (evaluating for var=A)
# DEBUG: DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: True
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 6, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 6 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 5, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 5 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 11, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 11 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: _find_single_match called with start_idx=4
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 2 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 6
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=6 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 6 Eq 50 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.044169 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [1], 'A': [2], 'B': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-14 00:00:00 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-14 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting first_a_date to 2020-05-14 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [1], 'A': [2], 'B': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.order_date, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-16 00:00:00 at index 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-16 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting first_b_date to 2020-05-16 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [1], 'A': [2], 'B': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.order_date, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-12 00:00:00 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting first_c_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:Applied column aliases: {'first_a_date': 'a_date', 'first_b_date': 'b_date', 'first_c_date': 'c_date'}
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.05115008354187012, 'automata_build_time': 0.07018828392028809, 'matching_time': 0.12779974937438965, 'result_processing_time': 0.013075113296508789, 'total_time': 0.2638270854949951, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 2, 'total_misses': 6, 'total_compilation_time_saved': 0.040502071380615234, 'memory_used_mb': 3.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 25.0% (2/8)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.041s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 3.00 MB
#   customer_id     a_date     b_date     c_date
# 0      cust_1 2020-05-14 2020-05-16 2020-05-12

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic = """
SELECT
  customer_id,
  start_price,
  last_b_price    AS peak_price,
  last_c_price    AS bottom_price,
  last_d_price    AS end_price,
  start_date,
  end_date
FROM memory.default.orders
MATCH_RECOGNIZE (
  PARTITION BY customer_id
  ORDER BY order_date
  MEASURES
    A.price               AS start_price,
    LAST(B.price)         AS last_b_price,
    LAST(C.price)         AS last_c_price,
    LAST(D.price)         AS last_d_price,
    A.order_date          AS start_date,
    LAST(D.order_date)    AS end_date
  PATTERN (A B+ C+ D+)
  DEFINE
    B AS B.price > PREV(price),
    C AS C.price < PREV(price),
    D AS D.price > PREV(price)
) AS t;

"""

print("Test 1:")
output_df = match_recognize(query_basic, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, start_price, last_b_price AS peak_price, last_c_price AS bottom_price, last_d_price AS end_price, start_date, end_date FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES A.price AS start_price, LAST(B.price) AS last_b_price, LAST(C.price) AS last_c_price, LAST(D.price) AS last_d_price, A.order_date AS start_date, LAST(D.order_date) AS end_date PATTERN (A B+ C+ D+) DEFINE B AS B.price > PREV(price), C AS C.price < PREV(price), D AS D.price > PREV(price) ) AS t;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=start_price, metadata={}), SelectItem(expression=last_b_price, alias=peak_price, metadata={}), SelectItem(expression=last_c_price, alias=bottom_price, metadata={}), SelectItem(expression=last_d_price, alias=end_price, metadata={}), SelectItem(expression=start_date, metadata={}), SelectItem(expression=end_date, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.price', alias='start_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.price)', alias='last_b_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(C.price)', alias='last_c_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(D.price)', alias='last_d_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='A.order_date', alias='start_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(D.order_date)', alias='end_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+ D+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C+ D+', metadata={'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='B.price > PREV(price)'), Define(variable='C', condition='C.price < PREV(price)'), Define(variable='D', condition='D.price > PREV(price)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+', 'D+'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+ D+
# DEBUG:src.parser.match_recognize_extractor:Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(B.price)': ['B', 'B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(C.price)': ['C', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(D.price)': ['D', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'A.order_date': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(D.order_date)': ['D', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'B.price > PREV(price)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'C.price < PREV(price)': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'D.price > PREV(price)': ['D']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'A', 'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(B.price)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(C.price)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(D.price)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.order_date
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(D.order_date)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 6 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_price: A.price
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_b_price: LAST(B.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_c_price: LAST(C.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_d_price: LAST(D.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_date: A.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure end_date: LAST(D.order_date)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'start_price': 'FINAL', 'last_b_price': 'FINAL', 'last_c_price': 'FINAL', 'last_d_price': 'FINAL', 'start_date': 'FINAL', 'end_date': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: A B+ C+ D+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 25.00%, Memory used: 3.00 MB, Cache size: 6/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=5, measures=6, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 200 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 100 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 50 (from row 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Lt 100 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: D
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=D, col_name=price, is_define_mode=True, current_var=D
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=3, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for D.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: D.price = 50 (from row 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Gt 100 = False (evaluating for var=D)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was D)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=price, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=4, ctx.variables={'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.price = 100 (from row 4)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 50 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: D
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=D, col_name=price, is_define_mode=True, current_var=D
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=4, ctx.variables={'A': [0], 'B': [1], 'C': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for D.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: D.price = 100 (from row 4)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 50 = True (evaluating for var=D)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for D
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was D)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition D: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable D
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 4 at row 4
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-4, vars: ['A', 'B', 'C', 'D']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 4, 'variables': {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}, 'state': 4, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 4, 'variables': {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}, 'state': 4, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_b_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_c_price to 50 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting last_d_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.order_date), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting end_date to 2020-05-17 00:00:00 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 4
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:start_price: 100
# INFO:row_match_recognize.src.matcher.matcher:last_b_price: 200
# INFO:row_match_recognize.src.matcher.matcher:last_c_price: 50
# INFO:row_match_recognize.src.matcher.matcher:last_d_price: 100
# INFO:row_match_recognize.src.matcher.matcher:start_date: 2020-05-11 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:end_date: 2020-05-17 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:4]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 5
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 5
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 5
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.053444 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'start_price': 100, 'last_b_price': 200, 'last_c_price': 50, 'last_d_price': 100, 'start_date': Timestamp('2020-05-11 00:00:00'), 'end_date': Timestamp('2020-05-17 00:00:00'), 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.price
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.price = 4 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 8
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), right=8 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 4 Gt 8 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: B.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: C.price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for D: D.price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'D'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=price, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [1]}
# ...
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.038770 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.price, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_b_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_c_price to 50 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.price), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_d_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.order_date, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-11 00:00:00 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-11 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-11 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(D.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(D.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(D.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(D.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2, 3], 'D': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(D.order_date), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_date to 2020-05-17 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:Applied column aliases: {'last_b_price': 'peak_price', 'last_c_price': 'bottom_price', 'last_d_price': 'end_price'}
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.016407012939453125, 'automata_build_time': 0.0010638236999511719, 'matching_time': 0.09833264350891113, 'result_processing_time': 0.018952131271362305, 'total_time': 0.1365976333618164, 'partition_count': 2, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 3, 'total_misses': 6, 'total_compilation_time_saved': 0.07722330093383789, 'memory_used_mb': 3.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (3/9)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.077s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 3.00 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1:
# Pattern value: 'A B+ C+ D+'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# Pattern value: 'A B+ C+ D+'
# Pattern variables {'A'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 3, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 3, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['D']
# DEBUG: Categorized transitions: {'accepting': [('D', 4, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: D -> state 4 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
#   customer_id  start_price  peak_price  bottom_price  end_price start_date  \
# 0      cust_1          100         200            50        100 2020-05-11
#
#     end_date
# 0 2020-05-17

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
import pandas as pd

# Define the data
data = [
    ('cust_1', '2020-05-11', 100),
    ('cust_1', '2020-05-12', 200),
    ('cust_2', '2020-05-13',   8),
    ('cust_1', '2020-05-14', 100),
    ('cust_2', '2020-05-15',   4),
    ('cust_1', '2020-05-16',  50),
    ('cust_1', '2020-05-17', 100),
    ('cust_2', '2020-05-18',   6),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['customer_id', 'order_date', 'price'])

# Convert order_date column to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Display the DataFrame
print(df)

query_basic_permute = """
SELECT customer_id, start_price, bottom_price, final_price, start_date, final_date
    FROM memory.default.orders
        MATCH_RECOGNIZE (
            PARTITION BY customer_id
            ORDER BY order_date
            MEASURES
                START.price AS start_price,
                LAST(DOWN.price) AS bottom_price,
                LAST(UP.price) AS final_price,
                START.order_date AS start_date,
                LAST(UP.order_date) AS final_date
            ONE ROW PER MATCH
            AFTER MATCH SKIP PAST LAST ROW
            PATTERN (START DOWN+ UP+)
            DEFINE
                DOWN AS price < PREV(price),
                UP AS price > PREV(price)
            );
"""

print("Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order")
output_df = match_recognize(query_basic_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT customer_id, start_price, bottom_price, final_price, start_date, final_date FROM memory.default.orders MATCH_RECOGNIZE ( PARTITION BY customer_id ORDER BY order_date MEASURES START.price AS start_price, LAST(DOWN.price) AS bottom_price, LAST(UP.price) AS final_price, START.order_date AS start_date, LAST(UP.order_date) AS final_date ONE ROW PER MATCH AFTER MATCH SKIP PAST LAST ROW PATTERN (START DOWN+ UP+) DEFINE DOWN AS price < PREV(price), UP AS price > PREV(price) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=customer_id, metadata={}), SelectItem(expression=start_price, metadata={}), SelectItem(expression=bottom_price, metadata={}), SelectItem(expression=final_price, metadata={}), SelectItem(expression=start_date, metadata={}), SelectItem(expression=final_date, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='START.price', alias='start_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(DOWN.price)', alias='bottom_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(UP.price)', alias='final_price', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='START.order_date', alias='start_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(UP.order_date)', alias='final_date', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracting AFTER MATCH SKIP clause: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Extracted AFTER MATCH SKIP: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['START', 'DOWN+', 'UP+'], 'base_variables': ['START', 'DOWN', 'UP']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: START DOWN+ UP+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='START DOWN+ UP+', metadata={'variables': ['START', 'DOWN+', 'UP+'], 'base_variables': ['START', 'DOWN', 'UP']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='DOWN', condition='price < PREV(price)'), Define(variable='UP', condition='price > PREV(price)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['START', 'DOWN+', 'UP+'], 'base_variables': ['START', 'DOWN', 'UP']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: START DOWN+ UP+
# DEBUG:src.parser.match_recognize_extractor:Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'START.price': ['START']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(DOWN.price)': ['DOWN', 'DOWN']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(UP.price)': ['UP', 'UP']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'START.order_date': ['START']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'LAST(UP.order_date)': ['UP', 'UP']
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price < PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'price > PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'UP', 'DOWN', 'START'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: {'UP', 'DOWN', 'START'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'UP', 'DOWN'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: START.price
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(DOWN.price)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(UP.price)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: START.order_date
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(UP.order_date)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_price: START.price
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure bottom_price: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure final_price: LAST(UP.price)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_date: START.order_date
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure final_date: LAST(UP.order_date)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'start_price': 'FINAL', 'bottom_price': 'FINAL', 'final_price': 'FINAL', 'start_date': 'FINAL', 'final_date': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: START DOWN+ UP+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='START', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='DOWN', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='UP', target=10, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [5, 6, 8, 9, 11] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [5, 7] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8, 9, 11] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [1, 9, 10, 12, 13] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [9, 11] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [1, 12, 13] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [1, 13] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='START', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='START', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='DOWN', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='DOWN', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='UP', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='DOWN', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='UP', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='UP', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='UP', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'START'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'START'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='START'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [6]: accept=False, variables={'DOWN'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='DOWN'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 2, variable='DOWN'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [1, 10] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [1, 10]: accept=True, variables={'UP'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 3, variable='UP'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [1, 10] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 3, variable='UP'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 4→4 states, 5→5 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 4 states, 5 transitions, 0.007s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0082s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 7
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=4, measures=5, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 5 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: START)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: START
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-11 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was START)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition START: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable START
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Lt 100 = False (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: START)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: START
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-12 00:00:00'), 'price': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was START)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition START: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable START
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-14 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=2
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=2, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1], 'DOWN': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Lt 100 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: UP
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = UP
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-16 00:00:00'), 'price': 50}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=3
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=2 (curr_idx=3, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 2: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=50 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 50 Gt 100 = False (evaluating for var=UP)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for UP
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was UP)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 4, data: {'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [1], 'DOWN': [2, 3]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 50 = False (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: UP
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = UP
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_1', 'order_date': Timestamp('2020-05-17 00:00:00'), 'price': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=3 (curr_idx=4, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 3: 50
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=50 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Gt 50 = True (evaluating for var=UP)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for UP
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was UP)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition UP: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 4 to variable UP
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 3 at row 4
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-4, vars: ['START', 'DOWN', 'UP']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 4, 'variables': {'START': [1], 'DOWN': [2, 3], 'UP': [4]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 4, 'variables': {'START': [1], 'DOWN': [2, 3], 'UP': [4]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.price, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_price to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 50 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting bottom_price to 50 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(UP.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(UP.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(UP.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(UP.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(UP.price), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting final_price to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.order_date, current_idx=4, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(UP.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(UP.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(UP.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(UP.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(UP.order_date), current_idx=4, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting final_date to 2020-05-17 00:00:00 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 4
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:start_price: 200
# INFO:row_match_recognize.src.matcher.matcher:bottom_price: 50
# INFO:row_match_recognize.src.matcher.matcher:final_price: 100
# INFO:row_match_recognize.src.matcher.matcher:start_date: 2020-05-12 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:final_date: 2020-05-17 00:00:00
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:4]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 5
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 5
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 5
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.055793 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'start_price': 200, 'bottom_price': 50, 'final_price': 100, 'start_date': Timestamp('2020-05-12 00:00:00'), 'final_date': Timestamp('2020-05-17 00:00:00'), 'MATCH_NUMBER': 1, '_original_row_idx': 1, 'customer_id': 'cust_1', '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for DOWN: price < PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for UP: price > PREV(price)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=True, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: START)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: START
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-13 00:00:00'), 'price': 8}
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for START
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was START)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition START: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable START
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-15 00:00:00'), 'price': 4}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'price' resolved to: 4
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(price, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 8
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=4 (<class 'int'>), right=8 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 4 Lt 8 = True (evaluating for var=DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was DOWN)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition DOWN: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'START': [0], 'DOWN': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = DOWN
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'customer_id': 'cust_2', 'order_date': Timestamp('2020-05-18 00:00:00'), 'price': 6}
# ...
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.order_date, current_idx=4, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for START
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-12 00:00:00 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-12 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-12 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(UP.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(UP.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(UP.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(UP.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [1], 'DOWN': [2, 3], 'UP': [4]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(UP.order_date), current_idx=4, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-17 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting final_date to 2020-05-17 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.price', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.price': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.price
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.price with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [5], 'DOWN': [6], 'UP': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.price, current_idx=7, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=price
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for START
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 8 at index 5
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 8 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_price to 8 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(DOWN.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(DOWN.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(DOWN.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(DOWN.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [5], 'DOWN': [6], 'UP': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(DOWN.price), current_idx=7, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 4 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting bottom_price to 4 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(UP.price)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(UP.price)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(UP.price)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(UP.price) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [5], 'DOWN': [6], 'UP': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(UP.price), current_idx=7, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 6 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting final_price to 6 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'START.order_date', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'START.order_date': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: START.order_date
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: START.order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: START.order_date with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [5], 'DOWN': [6], 'UP': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: START.order_date, current_idx=7, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=START, col=order_date
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for START
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 2020-05-13 00:00:00 at index 5
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-13 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_date to 2020-05-13 00:00:00 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(UP.order_date)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(UP.order_date)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(UP.order_date)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(UP.order_date) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'START': [5], 'DOWN': [6], 'UP': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(UP.order_date), current_idx=7, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2020-05-18 00:00:00 (type: <class 'pandas._libs.tslibs.timestamps.Timestamp'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting final_date to 2020-05-18 00:00:00 from evaluator
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.013956785202026367, 'automata_build_time': 0.025393009185791016, 'matching_time': 0.09914398193359375, 'result_processing_time': 0.027220487594604492, 'total_time': 0.1674361228942871, 'partition_count': 2, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 3, 'total_misses': 7, 'total_compilation_time_saved': 0.07722330093383789, 'memory_used_mb': 3.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 30.0% (3/10)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.077s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 3.50 MB
#   customer_id order_date  price
# 0      cust_1 2020-05-11    100
# 1      cust_1 2020-05-12    200
# 2      cust_2 2020-05-13      8
# 3      cust_1 2020-05-14    100
# 4      cust_2 2020-05-15      4
# 5      cust_1 2020-05-16     50
# 6      cust_1 2020-05-17    100
# 7      cust_2 2020-05-18      6
# Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order
# Pattern value: 'START DOWN+ UP+'
# Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# Pattern value: 'START DOWN+ UP+'
# Pattern variables {'START'} have no DEFINE conditions - defaulting to TRUE (always match)
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['START']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('START', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: START -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['START']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('START', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: START -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('DOWN', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: DOWN -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('DOWN', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: DOWN -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 4 with value N/A
# DEBUG: Found 1 valid transitions: ['UP']
# DEBUG: Categorized transitions: {'accepting': [('UP', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: UP -> state 3 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['START']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('START', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: START -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['DOWN']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('DOWN', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: DOWN -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['UP']
# DEBUG: Categorized transitions: {'accepting': [('UP', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: UP -> state 3 (alternation priority: N/A)
#   customer_id  start_price  bottom_price  final_price start_date final_date
# 0      cust_1          200            50          100 2020-05-12 2020-05-17
# 1      cust_2            8             4            6 2020-05-13 2020-05-18

# %% [markdown]
# # Example #2

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")

# Test 1: Basic PERMUTE - Match any order of A, B, C
query_basic_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order")
output_df = match_recognize(query_basic_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure a_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure b_value: B.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure c_value: C.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'a_value': 'FINAL', 'b_value': 'FINAL', 'c_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# Testing PERMUTE Patterns
#
# Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# DEBUG: _process_permute called with variables: ['A', 'B', 'C']
# DEBUG: Token metadata: {'variables': ['A', 'B', 'C'], 'variable_count': 3, 'original': 'PERMUTE(A, B, C)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=13, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=17, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=20, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=22, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=24, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=27, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=29, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=31, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=34, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=36, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=38, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=41, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=43, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=45, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=48, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=50, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=52, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 15)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 14)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 13)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4, 47] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7, 8] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 10] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 4, 11, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [15] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16, 17] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [17] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 4, 18, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [19] = [19, 20] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [20] = [20] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [21] = [21, 22] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [22] = [22] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23, 24] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [24] = [24] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 4, 25, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [26] = [26, 27] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [27] = [27] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28] = [28, 29] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [29] = [29] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30, 31] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [31] = [31] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 4, 32, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [33] = [33, 34] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [34] = [34] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [35] = [35, 36] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [36] = [36] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37, 38] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [38] = [38] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 4, 39, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [40] = [40, 41] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [41] = [41] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42] = [42, 43] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [43] = [43] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44, 45] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [45] = [45] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 4, 46, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [47] = [1, 47] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=9, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=18, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=23, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=25, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=30, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=32, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=37, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=39, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=44, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=46, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [35, 42]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [7, 14]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [21, 28]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [44]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 4, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 5 from NFA states [37]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 5, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 6 from NFA states [16]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 6, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 7 from NFA states [9]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 7, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 8 from NFA states [30]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 8, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 9 from NFA states [23]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 9, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 46] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 10 from NFA states [1, 46]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 10, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 39] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 11 from NFA states [1, 39]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 5: added transition to 11, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 12 from NFA states [1, 18]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 6: added transition to 12, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 13 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 7: added transition to 13, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 32] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 14 from NFA states [1, 32]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 8: added transition to 14, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 25] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 15 from NFA states [1, 25]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 9: added transition to 15, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:Merging 3 equivalent state pairs
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 16→13 states, 15→15 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 16 states, 15 transitions, 0.017s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0183s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 8
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# ...
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 175 at index 6
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 375 at index 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 375 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_value to 375 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 275 at index 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 275 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting c_value to 275 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 425 at index 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_value to 425 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 325 at index 10
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 325 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_value to 325 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 225 at index 9
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 225 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting c_value to 225 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.022976398468017578, 'automata_build_time': 0.06876277923583984, 'matching_time': 0.19064998626708984, 'result_processing_time': 0.06597709655761719, 'total_time': 0.35019850730895996, 'partition_count': 4, 'match_count': 4}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 3, 'total_misses': 8, 'total_compilation_time_saved': 0.07722330093383789, 'memory_used_mb': 4.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 27.3% (3/11)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.077s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 4.00 MB
#    seq  step pattern_var  match_num  a_value  b_value  c_value
# 0    1     1           C          1      100      200      300
# 1    2     1           C          1      150      250      350
# 2    3     1           B          1      175      375      275
# 3    4     1           A          1      425      325      225

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")

# Test 1: Basic PERMUTE - Match any order of A, B, C
query_basic_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
  
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order")
output_df = match_recognize(query_basic_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure a_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure b_value: B.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure c_value: C.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'a_value': 'FINAL', 'b_value': 'FINAL', 'c_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 27.27%, Memory used: 4.00 MB, Cache size: 8/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_value to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 300 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting c_value to 300 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1], 'C': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:a_value: 100
# INFO:row_match_recognize.src.matcher.matcher:b_value: 200
# INFO:row_match_recognize.src.matcher.matcher:c_value: 300
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.039393 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'pattern_var': 'C', 'match_num': 1, 'a_value': 100, 'b_value': 200, 'c_value': 300, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 1, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [0], 'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['B', 'A', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 150 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 150 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_value to 150 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 250 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 250 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_value to 250 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 350 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 350 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting c_value to 350 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'B': [0], 'A': [1], 'C': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:a_value: 150
# INFO:row_match_recognize.src.matcher.matcher:b_value: 250
# INFO:row_match_recognize.src.matcher.matcher:c_value: 350
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.036770 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=1, row_idx=0 to result: {'pattern_var': 'C', 'match_num': 1, 'a_value': 150, 'b_value': 250, 'c_value': 350, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 2, '_partition_index': 1, '_partition_row_index': 0}
# ...
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 175 at index 6
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 375 at index 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 375 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_value to 375 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 275 at index 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 275 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting c_value to 275 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 425 at index 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting a_value to 425 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 325 at index 10
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 325 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting b_value to 325 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 225 at index 9
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 225 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting c_value to 225 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'a_value', 'b_value', 'c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.008941650390625, 'automata_build_time': 0.0013093948364257812, 'matching_time': 0.17893195152282715, 'result_processing_time': 0.06740474700927734, 'total_time': 0.258685827255249, 'partition_count': 4, 'match_count': 4}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 4, 'total_misses': 8, 'total_compilation_time_saved': 0.14493036270141602, 'memory_used_mb': 4.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (4/12)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.145s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 4.00 MB
#    seq  step pattern_var  match_num  a_value  b_value  c_value
# 0    1     1           C          1      100      200      300
# 1    2     1           C          1      150      250      350
# 2    3     1           B          1      175      375      275
# 3    4     1           A          1      425      325      225

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 2: PERMUTE with Quantifier
query_permute_quantifier = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        FIRST(A.value) AS first_a_value,
        LAST(C.value) AS last_c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C)+)
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 2: PERMUTE with Quantifier - Should match one or more occurrences of permutations")
output_df = match_recognize(query_permute_quantifier, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, FIRST(A.value) AS first_a_value, LAST(C.value) AS last_c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)+) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='FIRST(A.value)', alias='first_a_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(C.value)', alias='last_c_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)+', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)+
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated FIRST\b usage in measure: FIRST(A.value)
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(C.value)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 4 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure first_a_value: FIRST(A.value)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure last_c_value: LAST(C.value)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'first_a_value': 'FINAL', 'last_c_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: PERMUTE(A, B, C)+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# Testing PERMUTE Patterns
#
# Test 2: PERMUTE with Quantifier - Should match one or more occurrences of permutations
# Pattern value: 'PERMUTE(A, B, C)+'
# Pattern value: 'PERMUTE(A, B, C)+'
# DEBUG: _process_permute called with variables: ['A', 'B', 'C']
# DEBUG: Token metadata: {'variables': ['A', 'B', 'C'], 'variable_count': 3, 'original': 'PERMUTE(A, B, C)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Processing quantified PERMUTE: PERMUTE(A, B, C) with quantifier +
# DEBUG: _process_permute called with variables: ['A', 'B', 'C']
# DEBUG: Token metadata: {'variables': ['A', 'B', 'C'], 'variable_count': 3, 'original': 'PERMUTE(A, B, C)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=17, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=19, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=22, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=24, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=26, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=29, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=31, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=33, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=36, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=38, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=40, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=43, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=45, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=47, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=50, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=52, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=54, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 47] (iterations: 16)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 47] (iterations: 15)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 13)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 3, 4, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 48, 49] (iterations: 17)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7, 8] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 10] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 3, 4, 5, 6, 11, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [15] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16, 17] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [17] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 3, 4, 5, 6, 12, 13, 18, 19, 20, 26, 27, 33, 34, 40, 41, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [19] = [19, 20] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [20] = [20] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [21] = [21, 22] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [22] = [22] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23, 24] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [24] = [24] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 3, 4, 5, 6, 12, 13, 19, 20, 25, 26, 27, 33, 34, 40, 41, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [26] = [26, 27] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [27] = [27] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28] = [28, 29] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [29] = [29] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30, 31] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [31] = [31] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 3, 4, 5, 6, 12, 13, 19, 20, 26, 27, 32, 33, 34, 40, 41, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [33] = [33, 34] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [34] = [34] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [35] = [35, 36] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [36] = [36] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37, 38] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [38] = [38] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 3, 4, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 39, 40, 41, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [40] = [40, 41] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [41] = [41] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42] = [42, 43] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [43] = [43] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44, 45] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [45] = [45] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 3, 4, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 46, 48, 49] (iterations: 18)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [47] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41, 47] (iterations: 14)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [48] = [1, 48, 49] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [49] = [1, 49] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=9, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=18, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=23, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=25, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=30, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=32, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=37, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=39, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=44, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=46, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [35, 42]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [7, 14]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [21, 28]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [44]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 4, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 5 from NFA states [37]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 5, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 6 from NFA states [16]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 6, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 7 from NFA states [9]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 7, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 8 from NFA states [30]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 8, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 9 from NFA states [23]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 9, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 46] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 10 from NFA states [1, 46]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 10, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 39] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 11 from NFA states [1, 39]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 5: added transition to 11, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 12 from NFA states [1, 18]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 6: added transition to 12, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 13 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 7: added transition to 13, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 32] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 14 from NFA states [1, 32]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 8: added transition to 14, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 25] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 15 from NFA states [1, 25]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 9: added transition to 15, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 10: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 10: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 10: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 11: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 11: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 11: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 12: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 12: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 12: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 13: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 13: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 13: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 14: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 14: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 14: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 15: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 15: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 15: added transition to 3, variable='B'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 16→16 states, 33→33 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 16 states, 33 transitions, 0.041s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0419s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 9
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=16, measures=4, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# ...
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [3], 'A': [4], 'C': [5]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 5
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.value), current_idx=5, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 350 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_c_value to 350 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'FIRST(A.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'FIRST(A.value)': <re.Match object; span=(0, 6), match='FIRST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: FIRST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function FIRST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: FIRST(A.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 175
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 275
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 6, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 6 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 375
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 12, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 12 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 225
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 325
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 4, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 4 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 425
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 10, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 10 (alternation priority: N/A)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: FIRST(A.value), current_idx=8, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting first_a_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.value)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.value), current_idx=8, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 275 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_c_value to 275 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'FIRST(A.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'FIRST(A.value)': <re.Match object; span=(0, 6), match='FIRST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: FIRST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function FIRST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: FIRST(A.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: FIRST(A.value), current_idx=11, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting first_a_value to 425 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(C.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(C.value)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(C.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(C.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(C.value), current_idx=11, is_running=False, is_permute=True
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 225 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting last_c_value to 225 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'first_a_value', 'last_c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'first_a_value', 'last_c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'first_a_value', 'last_c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'first_a_value', 'last_c_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.015810012817382812, 'automata_build_time': 0.10542583465576172, 'matching_time': 0.17601275444030762, 'result_processing_time': 0.040073394775390625, 'total_time': 0.339937686920166, 'partition_count': 4, 'match_count': 4}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 4, 'total_misses': 9, 'total_compilation_time_saved': 0.14493036270141602, 'memory_used_mb': 4.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 30.8% (4/13)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.145s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 4.50 MB
#    seq  step pattern_var  match_num  first_a_value  last_c_value
# 0    1     1           C          1            100           300
# 1    2     1           C          1            150           350
# 2    3     1           B          1            175           275
# 3    4     1           A          1            425           225

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 3: PERMUTE with ALL ROWS PER MATCH
query_permute_all_rows = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        RUNNING LAST(A.value) AS running_a_value
    ALL ROWS PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 3: PERMUTE with ALL ROWS PER MATCH - Shows all matched rows")
output_df = match_recognize(query_permute_all_rows, df)
print(output_df)
print("\n")
# Out:
# Testing PERMUTE Patterns
#
# Test 3: PERMUTE with ALL ROWS PER MATCH - Shows all matched rows
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, RUNNING LAST(A.value) AS running_a_value ALL ROWS PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='LAST(A.value)', alias='running_a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['B', 'C', 'A'], 'base_variables': ['B', 'C', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['B', 'C', 'A'], 'base_variables': ['B', 'C', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.value)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Initialized matcher with excluded variables: set()
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': []}
# Processing match 1 with ALL ROWS PER MATCH
# Excluded variables: set()
# Excluded rows: []
# Processing match 1, included indices: [0, 1, 2]
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=0, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 0 with RUNNING semantics: 100
# Added row 0 to results
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=1, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 100
# Added row 1 to results
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=2, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 100
# Added row 2 to results
# Find matches completed in 0.000770 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': []}
# Processing match 1 with ALL ROWS PER MATCH
# Excluded variables: set()
# Excluded rows: []
# Processing match 1, included indices: [0, 1, 2]
# Evaluated measure pattern_var for row 0 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=0, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 0 with RUNNING semantics: None
# Added row 0 to results
# Evaluated measure pattern_var for row 1 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=1, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 150
# Added row 1 to results
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=2, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 150
# Added row 2 to results
# Find matches completed in 0.000806 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': []}
# Processing match 1 with ALL ROWS PER MATCH
# Excluded variables: set()
# Excluded rows: []
# Processing match 1, included indices: [0, 1, 2]
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=0, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 0 with RUNNING semantics: 175
# Added row 0 to results
# Evaluated measure pattern_var for row 1 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=1, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 175
# Added row 1 to results
# Evaluated measure pattern_var for row 2 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=2, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 175
# Added row 2 to results
# Find matches completed in 0.000593 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': []}
# Processing match 1 with ALL ROWS PER MATCH
# Excluded variables: set()
# Excluded rows: []
# Processing match 1, included indices: [0, 1, 2]
# Evaluated measure pattern_var for row 0 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=0, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 0 with RUNNING semantics: None
# Added row 0 to results
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=1, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 1 with RUNNING semantics: None
# Added row 1 to results
# Evaluated measure pattern_var for row 2 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=2, is_running=True, is_permute=False
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 425
# Added row 2 to results
# Find matches completed in 0.000686 seconds
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# DEBUG: Set pattern_var=A for row 0
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# DEBUG: Set match_num=1 for row 0
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=0, is_running=True, is_permute=False
# DEBUG: Set running_a_value=100 for row 0
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# DEBUG: Set pattern_var=B for row 1
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# DEBUG: Set match_num=1 for row 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=1, is_running=True, is_permute=False
# DEBUG: Set running_a_value=100 for row 1
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# DEBUG: Set pattern_var=C for row 2
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# DEBUG: Set match_num=1 for row 2
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'B', 'C'], current_idx=2, is_running=True, is_permute=False
# DEBUG: Set running_a_value=100 for row 2
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# DEBUG: Set pattern_var=B for row 3
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# DEBUG: Set match_num=1 for row 3
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=3, is_running=True, is_permute=False
# DEBUG: Set running_a_value=None for row 3
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# DEBUG: Set pattern_var=A for row 4
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# DEBUG: Set match_num=1 for row 4
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=4, is_running=True, is_permute=False
# DEBUG: Set running_a_value=150 for row 4
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# DEBUG: Set pattern_var=C for row 5
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# DEBUG: Set match_num=1 for row 5
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# DEBUG_EVAL: expr='LAST(A.value)', vars=['B', 'A', 'C'], current_idx=5, is_running=True, is_permute=False
# DEBUG: Set running_a_value=150 for row 5
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# DEBUG: Set pattern_var=A for row 6
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# DEBUG: Set match_num=1 for row 6
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=6, is_running=True, is_permute=False
# DEBUG: Set running_a_value=175 for row 6
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# DEBUG: Set pattern_var=C for row 7
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# DEBUG: Set match_num=1 for row 7
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=7, is_running=True, is_permute=False
# DEBUG: Set running_a_value=175 for row 7
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# DEBUG: Set pattern_var=B for row 8
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# DEBUG: Set match_num=1 for row 8
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# DEBUG_EVAL: expr='LAST(A.value)', vars=['A', 'C', 'B'], current_idx=8, is_running=True, is_permute=False
# DEBUG: Set running_a_value=175 for row 8
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# DEBUG: Set pattern_var=C for row 9
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# DEBUG: Set match_num=1 for row 9
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=9, is_running=True, is_permute=False
# DEBUG: Set running_a_value=None for row 9
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# DEBUG: Set pattern_var=B for row 10
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# DEBUG: Set match_num=1 for row 10
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=10, is_running=True, is_permute=False
# DEBUG: Set running_a_value=None for row 10
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# DEBUG: Set pattern_var=A for row 11
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# DEBUG: Set match_num=1 for row 11
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# DEBUG_EVAL: expr='LAST(A.value)', vars=['C', 'B', 'A'], current_idx=11, is_running=True, is_permute=False
# DEBUG: Set running_a_value=425 for row 11
#
# DEBUG: Checking measure columns in final DataFrame:
#   Measure 'pattern_var' exists with values: ['A', 'B', 'C']
#   Measure 'match_num' exists with values: [1, 1, 1]
#   Measure 'running_a_value' exists with values: [100.0, 100.0, 100.0]
# Query execution metrics: {'parsing_time': 0.021404504776000977, 'automata_build_time': 0.0007393360137939453, 'matching_time': 0.0068035125732421875, 'result_processing_time': 0.004071950912475586, 'total_time': 0.03362536430358887, 'partition_count': 4, 'match_count': 4}
#     seq  step pattern_var  match_num  running_a_value  id event_type  value
# 0     1     1           A          1            100.0   1      start    100
# 1     1     2           B          1            100.0   2     middle    200
# 2     1     3           C          1            100.0   3        end    300
# 3     2     1           B          1              NaN   4     middle    250
# 4     2     2           A          1            150.0   5      start    150
# 5     2     3           C          1            150.0   6        end    350
# 6     3     1           A          1            175.0   7      start    175
# 7     3     2           C          1            175.0   8        end    275
# 8     3     3           B          1            175.0   9     middle    375
# 9     4     1           C          1              NaN  10        end    225
# 10    4     2           B          1              NaN  11     middle    325
# 11    4     3           A          1            425.0  12      start    425

# %% [markdown]
# # check

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 4: PERMUTE with Subset Variables
query_permute_subset = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        X.value AS x_value,
        Y.value AS y_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    SUBSET
        X = (A, B),
        Y = (B, C)
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 4: PERMUTE with Subset Variables - Using subset groupings")
output_df = match_recognize(query_permute_subset, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, X.value AS x_value, Y.value AS y_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) SUBSET X = (A, B), Y = (B, C) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='X.value', alias='x_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='Y.value', alias='y_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='X = (A, B)'), SubsetClause(subset_text='Y = (B, C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: X.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: Y.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 4 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure x_value: X.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure y_value: Y.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'x_value': 'FINAL', 'y_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 28.57%, Memory used: 5.00 MB, Cache size: 10/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=4, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'X.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'X.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: X.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: X.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: X.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: X.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=X, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for X
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting x_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'Y.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'Y.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: Y.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: Y.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: Y.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: Y.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=Y, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for Y
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting y_value to 200 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1], 'C': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:x_value: 100
# INFO:row_match_recognize.src.matcher.matcher:y_value: 200
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.036988 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'pattern_var': 'C', 'match_num': 1, 'x_value': 100, 'y_value': 200, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 1, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [0], 'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['B', 'A', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'X.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'X.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: X.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: X.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: X.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: X.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=X, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for X
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 150 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting x_value to 150 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'Y.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'Y.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: Y.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: Y.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: Y.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: Y.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=Y, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for Y
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 250 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting y_value to 250 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'B': [0], 'A': [1], 'C': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:x_value: 150
# INFO:row_match_recognize.src.matcher.matcher:y_value: 250
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.035221 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=1, row_idx=0 to result: {'pattern_var': 'C', 'match_num': 1, 'x_value': 150, 'y_value': 250, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 2, '_partition_index': 1, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# ...
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'X.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'X.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: X.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: X.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: X.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: X.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=X, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for X
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting x_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'Y.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'Y.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: Y.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: Y.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: Y.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: Y.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=Y, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for Y
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 375 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting y_value to 375 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'X.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'X.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: X.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: X.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: X.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: X.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=X, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for X
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting x_value to 425 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'Y.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'Y.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: Y.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: Y.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: Y.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: Y.value, current_idx=11, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=Y, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for Y
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 325 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting y_value to 325 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'x_value', 'y_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'x_value', 'y_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'x_value', 'y_value']
# Testing PERMUTE Patterns
#
# Test 4: PERMUTE with Subset Variables - Using subset groupings
# Pattern value: 'PERMUTE(A, B, C)'
# Extracted subset definition: X = (A, B)
# Extracted subset definition: Y = (B, C)
# Pattern value: 'PERMUTE(A, B, C)'
# DEBUG: DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: True
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 100
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 200
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 7, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 7 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 300
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 12, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 12 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 250
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 3, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 150
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 9, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 9 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 350
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 12, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 12 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 175
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 275
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 6, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 6 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 375
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 11, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 11 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 225
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 325
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 4, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 4 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 425
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 10, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 10 (alternation priority: N/A)
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'x_value', 'y_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.009966611862182617, 'automata_build_time': 0.0013935565948486328, 'matching_time': 0.15102434158325195, 'result_processing_time': 0.04270362854003906, 'total_time': 0.20658516883850098, 'partition_count': 4, 'match_count': 4}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 5, 'total_misses': 10, 'total_compilation_time_saved': 0.22166013717651367, 'memory_used_mb': 5.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (5/15)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.222s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 5.00 MB
#    seq  step pattern_var  match_num  x_value  y_value
# 0    1     1           C          1      100      200
# 1    2     1           C          1      150      250
# 2    3     1           B          1      175      375
# 3    4     1           A          1      425      325

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 5: Nested PERMUTE patterns
query_nested_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, PERMUTE(B, C)))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 5: Nested PERMUTE - Testing nested permutation patterns")
output_df = match_recognize(query_nested_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, PERMUTE(B, C))) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': True}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, PERMUTE(B, C))', metadata={'variables': ['A', 'PERMUTE(B', 'C'], 'base_variables': ['A', 'PERMUTE(B', 'C'], 'permute': True, 'nested_permute': True})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': True}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure a_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure b_value: B.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure c_value: C.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'a_value': 'FINAL', 'b_value': 'FINAL', 'c_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: PERMUTE(A, PERMUTE(B, C))
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 31.25%, Memory used: 5.50 MB, Cache size: 11/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=0, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=0, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_value to None from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=0, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting c_value to None from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 0
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:a_value: 100
# INFO:row_match_recognize.src.matcher.matcher:b_value: None
# INFO:row_match_recognize.src.matcher.matcher:c_value: None
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:0]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 1
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 1
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 1
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.045302 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'pattern_var': 'A', 'match_num': 1, 'a_value': 100, 'b_value': None, 'c_value': None, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 1, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 1, 'variables': {'A': [1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 1, 'variables': {'A': [1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 150 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 150 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_value to 150 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_value to None from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting c_value to None from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:a_value: 150
# INFO:row_match_recognize.src.matcher.matcher:b_value: None
# INFO:row_match_recognize.src.matcher.matcher:c_value: None
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# ...
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 2-2, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 2, 'end': 2, 'variables': {'A': [2]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 2, 'end': 2, 'variables': {'A': [2]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 425 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting a_value to 425 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting b_value to None from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting c_value to None from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# Testing PERMUTE Patterns
#
# Test 5: Nested PERMUTE - Testing nested permutation patterns
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# DEBUG: DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: True
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 100
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 200
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value 200
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value 300
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 250
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value 150
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value 350
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value 350
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 175
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value 275
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value 275
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value 375
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value 225
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value 325
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value 425
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# INFO:row_match_recognize.src.matcher.matcher:Match start: 2, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:a_value: 425
# INFO:row_match_recognize.src.matcher.matcher:b_value: None
# INFO:row_match_recognize.src.matcher.matcher:c_value: None
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 2
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[2:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 2 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 3, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.053742 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=3, row_idx=0 to result: {'pattern_var': 'A', 'match_num': 1, 'a_value': 425, 'b_value': None, 'c_value': None, 'MATCH_NUMBER': 1, '_original_row_idx': 2, 'seq': 4, '_partition_index': 3, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Rejecting match with sequence ['A']: inner variables ['B', 'C'] are not adjacent
# DEBUG:row_match_recognize.src.executor.match_recognize:Rejecting match with sequence ['A']: inner variables ['B', 'C'] are not adjacent
# DEBUG:row_match_recognize.src.executor.match_recognize:Rejecting match with sequence ['A']: inner variables ['B', 'C'] are not adjacent
# DEBUG:row_match_recognize.src.executor.match_recognize:Rejecting match with sequence ['A']: inner variables ['B', 'C'] are not adjacent
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.009740829467773438, 'automata_build_time': 0.0008089542388916016, 'matching_time': 0.1966710090637207, 'result_processing_time': 0.0009000301361083984, 'total_time': 0.21031832695007324, 'partition_count': 4, 'match_count': 0}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 6, 'total_misses': 11, 'total_compilation_time_saved': 0.23941826820373535, 'memory_used_mb': 5.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 35.3% (6/17)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.239s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 5.50 MB
# Empty DataFrame
# Columns: [seq, pattern_var, match_num, a_value, b_value, c_value]
# Index: []

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 6: PERMUTE with Complex Conditions
query_permute_complex = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS start_value,
        B.value AS middle_value,
        C.value AS end_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start' AND A.value < NEXT(A.value),
        B AS event_type = 'middle' AND B.value > PREV(B.value),
        C AS event_type = 'end' AND C.value > FIRST(A.value)
);
"""

print("Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS start_value, B.value AS middle_value, C.value AS end_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start' AND A.value < NEXT(A.value), B AS event_type = 'middle' AND B.value > PREV(B.value), C AS event_type = 'end' AND C.value > FIRST(A.value) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='start_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='middle_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='end_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start' AND A.value < NEXT(A.value)"), Define(variable='B', condition="event_type = 'middle' AND B.value > PREV(B.value)"), Define(variable='C', condition="event_type = 'end' AND C.value > FIRST(A.value)")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure middle_value: B.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure end_value: C.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'start_value': 'FINAL', 'middle_value': 'FINAL', 'end_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# Testing PERMUTE Patterns
#
# Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# DEBUG: _process_permute called with variables: ['A', 'B', 'C']
# DEBUG: Token metadata: {'variables': ['A', 'B', 'C'], 'variable_count': 3, 'original': 'PERMUTE(A, B, C)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=13, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=17, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=20, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=22, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=24, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=27, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=29, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=31, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=34, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=36, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=38, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=41, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=43, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=45, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=48, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=50, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=52, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 15)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 14)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 13)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4, 47] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7, 8] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 10] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 4, 11, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [15] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16, 17] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [17] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 4, 18, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [19] = [19, 20] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [20] = [20] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [21] = [21, 22] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [22] = [22] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23, 24] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [24] = [24] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 4, 25, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [26] = [26, 27] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [27] = [27] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28] = [28, 29] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [29] = [29] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30, 31] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [31] = [31] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 4, 32, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [33] = [33, 34] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [34] = [34] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [35] = [35, 36] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [36] = [36] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37, 38] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [38] = [38] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 4, 39, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [40] = [40, 41] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [41] = [41] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42] = [42, 43] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [43] = [43] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44, 45] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [45] = [45] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 4, 46, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [47] = [1, 47] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=9, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=18, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=23, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=25, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=30, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=32, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=37, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=39, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=44, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=46, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [35, 42]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [7, 14]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [21, 28]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [44]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 4, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 5 from NFA states [37]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 5, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 6 from NFA states [16]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 6, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 7 from NFA states [9]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 7, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 8 from NFA states [30]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 8, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 9 from NFA states [23]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 9, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 46] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 10 from NFA states [1, 46]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 10, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 39] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 11 from NFA states [1, 39]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 5: added transition to 11, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 12 from NFA states [1, 18]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 6: added transition to 12, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 13 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 7: added transition to 13, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 32] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 14 from NFA states [1, 32]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 8: added transition to 14, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 25] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 15 from NFA states [1, 25]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 9: added transition to 15, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:Merging 3 equivalent state pairs
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 16→13 states, 15→15 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 16 states, 15 transitions, 0.021s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0224s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 12
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-reference detected in C: references {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-references detected - recommending backtracking
# DEBUG:row_match_recognize.src.matcher.matcher:Starting backtracking search from row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Found 3 transitions from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 1: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 2: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 3: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 2 transitions from state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 6: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 7: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 7 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 12: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=12, assignments={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=value, is_define_mode=True, current_var=A
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=0, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for A.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: A.value = 100 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: NEXT(value, 1) at current_idx=0
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=0, nav=NEXT, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for A at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for B at row 1: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=value, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.value = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(value, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for B at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for C at row 2: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=value, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.value = 300 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] _get_navigation_value: var_name=A, column=value, nav_type=FIRST, steps=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Context state: current_idx=2, mode=DEFINE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Building optimized timeline from variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Built timeline with 3 entries
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Logical navigation: FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Returning result: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=300 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 300 Gt 100 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for C at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('A', 'value'), ('A', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable A already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('B', 'value'), ('B', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'B' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added B (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'B' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added B (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('C', 'value'), ('A', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'C' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added C (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable C already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation passed
# DEBUG:row_match_recognize.src.matcher.matcher:Found valid match with backtracking at depth 3
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'backtracking_used': True, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# ...
# DEBUG: After sorting, successors order:
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 0: vars=['C', 'A'], last_var=A, priority=999
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 1: vars=['C', 'B'], last_var=B, priority=999
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: True
# DEBUG: Using backtracking matcher for complex pattern
# DEBUG: Starting backtracking search with 3 rows, max_iterations=5000
# DEBUG: Before sorting, 3 successors found
# DEBUG: Successor 0: vars=['C'], last_var=C, row=3
# DEBUG: Successor 1: vars=['A'], last_var=A, row=3
# DEBUG: Successor 2: vars=['B'], last_var=B, row=3
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: After sorting, successors order:
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 0: vars=['A'], last_var=A, priority=999
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 1: vars=['B'], last_var=B, priority=999
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 2: vars=['C'], last_var=C, priority=999
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting middle_value to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 300 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_value to 300 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 175 at index 6
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 375 at index 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 375 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting middle_value to 375 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 275 at index 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 275 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_value to 275 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.02172565460205078, 'automata_build_time': 0.0726921558380127, 'matching_time': 0.19661235809326172, 'result_processing_time': 0.0454404354095459, 'total_time': 0.33812832832336426, 'partition_count': 4, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 6, 'total_misses': 12, 'total_compilation_time_saved': 0.23941826820373535, 'memory_used_mb': 6.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (6/18)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.239s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 6.00 MB
#    seq  step pattern_var  match_num  start_value  middle_value  end_value
# 0    1     1           C          1          100           200        300
# 1    3     1           B          1          175           375        275

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 6: PERMUTE with Complex Conditions
query_permute_complex = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS start_value,
        B.value AS middle_value,
        C.value AS end_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start' AND A.value < NEXT(A.value),
        B AS event_type = 'middle' AND B.value > PREV(B.value),
        C AS event_type = 'end' AND C.value > FIRST(A.value)
);
"""

print("Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS start_value, B.value AS middle_value, C.value AS end_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start' AND A.value < NEXT(A.value), B AS event_type = 'middle' AND B.value > PREV(B.value), C AS event_type = 'end' AND C.value > FIRST(A.value) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='start_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='middle_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='end_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start' AND A.value < NEXT(A.value)"), Define(variable='B', condition="event_type = 'middle' AND B.value > PREV(B.value)"), Define(variable='C', condition="event_type = 'end' AND C.value > FIRST(A.value)")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure start_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure middle_value: B.value
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure end_value: C.value
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'start_value': 'FINAL', 'middle_value': 'FINAL', 'end_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: PERMUTE(A, B, C)
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 33.33%, Memory used: 6.00 MB, Cache size: 12/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-reference detected in C: references {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-references detected - recommending backtracking
# DEBUG:row_match_recognize.src.matcher.matcher:Starting backtracking search from row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Found 3 transitions from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 1: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 2: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 3: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 2 transitions from state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 6: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 7: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 7 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 12: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=12, assignments={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=A, col_name=value, is_define_mode=True, current_var=A
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=0, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for A.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: A.value = 100 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: NEXT(value, 1) at current_idx=0
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=1 (curr_idx=0, nav=NEXT, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 1: 200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=100 (<class 'int'>), right=200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 100 Lt 200 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for A at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for B at row 1: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=value, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=1, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.value = 200 (from row 1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(value, 1) at current_idx=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=0 (curr_idx=1, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: returning value from row 0: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=200 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 200 Gt 100 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for B at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for C at row 2: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=C, col_name=value, is_define_mode=True, current_var=C
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=2, ctx.variables={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for C.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: C.value = 300 (from row 2)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] _get_navigation_value: var_name=A, column=value, nav_type=FIRST, steps=1
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Context state: current_idx=2, mode=DEFINE
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Building optimized timeline from variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Built timeline with 3 entries
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Logical navigation: FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[NAV_ENHANCED] Returning result: 100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=300 (<class 'int'>), right=100 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 300 Gt 100 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition passed for C at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('A', 'value'), ('A', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable A already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('B', 'value'), ('B', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'B' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added B (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'B' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added B (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Validating condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Extracting variables from condition: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Found potential variable references: [('C', 'value'), ('A', 'value')]
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'C' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added C (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Checking if 'A' is a pattern variable
# DEBUG:row_match_recognize.src.matcher.matcher:  Added A (from defined_variables)
# DEBUG:row_match_recognize.src.matcher.matcher:Final referenced variables: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced variables: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable C already validated via deferred validation
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation passed
# DEBUG:row_match_recognize.src.matcher.matcher:Found valid match with backtracking at depth 3
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'backtracking_used': True, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting start_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting middle_value to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 300 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting end_value to 300 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0], 'B': [1], 'C': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:start_value: 100
# INFO:row_match_recognize.src.matcher.matcher:middle_value: 200
# INFO:row_match_recognize.src.matcher.matcher:end_value: 300
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.041477 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'pattern_var': 'C', 'match_num': 1, 'start_value': 100, 'middle_value': 200, 'end_value': 300, 'MATCH_NUMBER': 1, '_original_row_idx': 0, 'seq': 1, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-reference detected in C: references {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-references detected - recommending backtracking
# DEBUG:row_match_recognize.src.matcher.matcher:Starting backtracking search from row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Found 3 transitions from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 1: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 2: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 3: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 2 transitions from state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 6: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 7: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 7 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 12: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=12, assignments={'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 12
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 6 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 11: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 11 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'A': [0], 'C': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=11, assignments={'A': [0], 'C': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq start = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for A at row 0: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 11
# DEBUG:row_match_recognize.src.matcher.matcher:Found 2 transitions from state 3 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 8: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 9: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 9 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C -> 12: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=12, assignments={'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for B at row 0: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=value, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=0, ctx.variables={'B': [0], 'A': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.value = 250 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=250 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(value, 1) at current_idx=0
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=-1 (curr_idx=0, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx -1 out of bounds [0, 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=250 (<class 'int'>), right=None (<class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 250 Gt None = None (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for B at row 0: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 12
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 8 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 10: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 10 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'B': [0], 'C': [1], 'A': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=10, assignments={'B': [0], 'C': [1], 'A': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for B at row 0: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] _get_variable_column_value: var_name=B, col_name=value, is_define_mode=True, current_var=B
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] ctx.current_idx=0, ctx.variables={'B': [0], 'C': [1], 'A': [2]}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] DEFINE mode - self-reference for B.value
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] Self-reference value: B.value = 250 (from row 0)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=250 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: PREV(value, 1) at current_idx=0
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx=-1 (curr_idx=0, nav=PREV, steps=1)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:PHYSICAL_NAV: target_idx -1 out of bounds [0, 3)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=250 (<class 'int'>), right=None (<class 'NoneType'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 250 Gt None = None (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for B at row 0: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 10
# DEBUG:row_match_recognize.src.matcher.matcher:Found 2 transitions from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 4: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 5: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 5 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B -> 11: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 11 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'C': [0], 'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=11, assignments={'C': [0], 'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for C at row 0: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for C at row 0: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 11
# DEBUG:row_match_recognize.src.matcher.matcher:Found 1 transitions from state 4 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A -> 10: deferred complex condition
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 10 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Variable assignments: {'C': [0], 'B': [1], 'A': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Validating complete match: state=10, assignments={'C': [0], 'B': [1], 'A': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor validation - has _anchor_metadata: True
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Checking 3 DEFINE conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating 3 deferred conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Validating deferred condition for C at row 0: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:Deferred DEFINE condition failed for C at row 0: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:Match validation failed at accepting state 10
# DEBUG:row_match_recognize.src.matcher.matcher:Backtracking search failed after exploring 16 states
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start' AND A.value < NEXT(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle' AND B.value > PREV(B.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end' AND C.value > FIRST(A.value)
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:  Has navigation functions: True
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-reference detected in C: references {'A', 'C'}
# DEBUG:row_match_recognize.src.matcher.matcher:Complex back-references detected - recommending backtracking
# DEBUG:row_match_recognize.src.matcher.matcher:Starting backtracking search from row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Found 3 transitions from state 0 at row 1
# ...
# DEBUG: _needs_backtracking returned: True
# DEBUG: Using backtracking matcher for complex pattern
# DEBUG: Starting backtracking search with 3 rows, max_iterations=5000
# DEBUG: Before sorting, 3 successors found
# DEBUG: Successor 0: vars=['C'], last_var=C, row=3
# DEBUG: Successor 1: vars=['A'], last_var=A, row=3
# DEBUG: Successor 2: vars=['B'], last_var=B, row=3
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: After sorting, successors order:
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 0: vars=['A'], last_var=A, priority=999
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 1: vars=['B'], last_var=B, priority=999
# DEBUG: Using individual variable priority 999 for non-PERMUTE
# DEBUG: Successor 2: vars=['C'], last_var=C, priority=999
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 100 at index 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_value to 100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 200 at index 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting middle_value to 200 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=2, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 300 at index 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_value to 300 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for A
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 175 at index 6
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 175 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting start_value to 175 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'B.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'B.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: B.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: B.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: B.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: B.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=B, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for B
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 375 at index 8
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 375 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting middle_value to 375 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'C.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'C.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: C.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: C.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: C.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [6], 'C': [7], 'B': [8]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 8
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: C.value, current_idx=8, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=C, col=value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Using PERMUTE-specific logic for C
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:PERMUTE match found value 275 at index 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 275 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting end_value to 275 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['seq'], ORDER BY: ['step'], MEASURES: ['pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['id', 'seq', 'value', 'step', 'event_type', 'pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num', 'start_value', 'middle_value', 'end_value']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.012880802154541016, 'automata_build_time': 0.0013518333435058594, 'matching_time': 0.1899423599243164, 'result_processing_time': 0.029779434204101562, 'total_time': 0.23566365242004395, 'partition_count': 4, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 7, 'total_misses': 12, 'total_compilation_time_saved': 0.3108522891998291, 'memory_used_mb': 6.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 36.8% (7/19)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.311s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 6.00 MB
#    seq  step pattern_var  match_num  start_value  middle_value  end_value
# 0    1     1           C          1          100           200        300
# 1    3     1           B          1          175           375        275

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data for PERMUTE with subset variables
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE with Subset Variables - Trino Compatibility\n")


# Test 7: PERMUTE with Edge Cases
query_permute_edge_cases = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        LAST(B.value) AS last_b_value,
        FIRST(C.value) AS first_c_value
    ALL ROWS PER MATCH
    PATTERN (PERMUTE(A, B?, C?))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 7: PERMUTE with Edge Cases - Testing optional elements")
output_df = match_recognize(query_permute_edge_cases, df)
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, LAST(B.value) AS last_b_value, FIRST(C.value) AS first_c_value ALL ROWS PER MATCH PATTERN (PERMUTE(A, B?, C?)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.value)', alias='last_b_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='FIRST(C.value)', alias='first_c_value', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B?, C?)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B?, C?)', metadata={'variables': ['A', 'B?', 'C?'], 'base_variables': ['A', 'B?', 'C?'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C', 'B'], 'base_variables': ['A', 'C', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B?, C?)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:Validated LAST\b usage in measure: LAST(B.value)
# DEBUG:src.parser.match_recognize_extractor:Validated FIRST\b usage in measure: FIRST(C.value)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Other function: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:Other function: FINAL semantics for measure match_num: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.executor.match_recognize:Other function: FINAL semantics for measure a_value: A.value
# DEBUG:row_match_recognize.src.executor.match_recognize:Navigation function: FINAL semantics for measure last_b_value: LAST(B.value)
# DEBUG:row_match_recognize.src.executor.match_recognize:Navigation function: FINAL semantics for measure first_c_value: FIRST(C.value)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'a_value': 'FINAL', 'last_b_value': 'FINAL', 'first_c_value': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: PERMUTE(A, B?, C?)
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# Testing PERMUTE with Subset Variables - Trino Compatibility
#
# Test 7: PERMUTE with Edge Cases - Testing optional elements
# Pattern value: 'PERMUTE(A, B?, C?)'
# Pattern value: 'PERMUTE(A, B?, C?)'
# DEBUG: _process_permute called with variables: ['A', 'B?', 'C?']
# DEBUG: Token metadata: {'variables': ['A', 'B?', 'C?'], 'variable_count': 3, 'original': 'PERMUTE(A, B?, C?)', 'has_nested': False, 'has_alternations': False, 'nested': False, 'depth': 0}
# DEBUG: Token type: PatternTokenType.PERMUTE
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=10, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=13, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=17, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=20, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=22, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=24, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=27, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=29, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=31, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=34, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=36, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=38, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=41, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=43, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=45, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=48, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=50, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=52, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 15)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 14)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 5, 6, 12, 13, 19, 20, 26, 27, 33, 34, 40, 41] (iterations: 13)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4, 47] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7, 8] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 10] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 4, 11, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12, 13] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [13] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14, 15] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [15] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16, 17] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [17] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 4, 18, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [19] = [19, 20] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [20] = [20] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [21] = [21, 22] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [22] = [22] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23, 24] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [24] = [24] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 4, 25, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [26] = [26, 27] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [27] = [27] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28] = [28, 29] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [29] = [29] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30, 31] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [31] = [31] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 4, 32, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [33] = [33, 34] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [34] = [34] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [35] = [35, 36] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [36] = [36] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37, 38] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [38] = [38] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 4, 39, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [40] = [40, 41] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [41] = [41] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42] = [42, 43] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [43] = [43] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44, 45] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [45] = [45] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 4, 46, 47] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [47] = [1, 47] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=7, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=9, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=14, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=18, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=21, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=23, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=25, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=28, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=30, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=32, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=35, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=37, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=39, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=42, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=44, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=46, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [42, 35] = [35, 42] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [35, 42]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14, 7] = [7, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [7, 14]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 2, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [28, 21] = [21, 28] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [21, 28]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [44] = [44] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [44]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 4, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [37] = [37] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 5 from NFA states [37]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 5, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [16] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 6 from NFA states [16]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 6, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 7 from NFA states [9]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 7, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [30] = [30] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 8 from NFA states [30]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 8, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [23] = [23] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 9 from NFA states [23]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 9, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [46] = [1, 46] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 10 from NFA states [1, 46]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 10, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [39] = [1, 39] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 11 from NFA states [1, 39]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 5: added transition to 11, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 12 from NFA states [1, 18]: accept=True, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 6: added transition to 12, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 13 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 7: added transition to 13, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [32] = [1, 32] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 14 from NFA states [1, 32]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 8: added transition to 14, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [25] = [1, 25] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 15 from NFA states [1, 25]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 9: added transition to 15, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:Merging 3 equivalent state pairs
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 16→13 states, 15→15 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 16 states, 15 transitions, 0.017s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0176s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 13
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=13, measures=5, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 3 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: event_type = 'start'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: event_type = 'middle'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: event_type = 'end'
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: C)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=start (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq start = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: start
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=start (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: start Eq middle = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq end = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: middle
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=middle (<class 'str'>), right=middle (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: middle Eq middle = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'event_type' resolved to: end
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), op=Eq
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=end (<class 'str'>), right=end (<class 'str'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: end Eq end = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 12 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 12, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1, 2]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1, 2]
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 0 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 0: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'B': [1], 'C': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 0 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'a_value' = 'A.value' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# ...
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set pattern_var=B for row 10 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 10
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set match_num=1 for row 10 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 10
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=10, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: None (type: <class 'NoneType'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set a_value=None for row 10 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.value)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 10
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.value), current_idx=10, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 325 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set last_b_value=325 for row 10 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'FIRST(C.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'FIRST(C.value)': <re.Match object; span=(0, 6), match='FIRST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: FIRST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function FIRST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: FIRST(C.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: FIRST(C.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 10
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: FIRST(C.value), current_idx=10, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 225 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set first_c_value=225 for row 10 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Row 11 - Full variables: {'C': [9], 'B': [10], 'A': [11]}, Running variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set pattern_var=A for row 11 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set match_num=1 for row 11 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'A.value', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'A.value': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: A.value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: A.value
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: A.value with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: A.value, current_idx=11, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Pattern variable reference matched: var=A, col=value
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 425 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set a_value=425 for row 11 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'LAST(B.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'LAST(B.value)': <re.Match object; span=(0, 5), match='LAST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: LAST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function LAST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: LAST(B.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: LAST(B.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: LAST(B.value), current_idx=11, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 325 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set last_b_value=325 for row 11 with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'FIRST(C.value)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'FIRST(C.value)': <re.Match object; span=(0, 6), match='FIRST('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: FIRST, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function FIRST not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: FIRST(C.value)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: FIRST(C.value) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'C': [9], 'B': [10], 'A': [11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 12
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: FIRST(C.value), current_idx=11, is_running=False, is_permute=False
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 225 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:DEBUG: Set first_c_value=225 for row 11 with FINAL semantics
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'pattern_var' exists with values: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'match_num' exists with values: [1, 1, 1]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'a_value' exists with values: [100, 100, 100]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'last_b_value' exists with values: [None, 200, 200]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'first_c_value' exists with values: [None, None, 300]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['seq', 'step', 'pattern_var', 'match_num', 'a_value', 'last_b_value', 'first_c_value', 'id', 'value', 'event_type']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=False, sort_columns=['MATCH_NUMBER', 'seq', 'step']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.015801429748535156, 'automata_build_time': 0.06780266761779785, 'matching_time': 0.3617129325866699, 'result_processing_time': 0.18826580047607422, 'total_time': 0.636549711227417, 'partition_count': 4, 'match_count': 4}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 7, 'total_misses': 13, 'total_compilation_time_saved': 0.3108522891998291, 'memory_used_mb': 6.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 35.0% (7/20)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.311s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 6.50 MB
#     seq  step pattern_var  match_num a_value last_b_value first_c_value  id  \
# 0     1     1           A          1     100         None          None   1
# 1     1     2           B          1     100          200          None   2
# 2     1     3           C          1     100          200           300   3
# 3     2     1           B          1    None          250          None   4
# 4     2     2           A          1     150          250          None   5
# 5     2     3           C          1     150          250           350   6
# 6     3     1           A          1     175         None          None   7
# 7     3     2           C          1     175         None           275   8
# 8     3     3           B          1     175          375           275   9
# 9     4     1           C          1    None         None           225  10
# 10    4     2           B          1    None          325           225  11
# 11    4     3           A          1     425          325           225  12
#
#     value event_type
# 0     100      start
# 1     200     middle
# 2     300        end
# 3     250     middle
# 4     150      start
# 5     350        end
# 6     175      start
# 7     275        end
# 8     375     middle
# 9     225        end
# 10    325     middle
# 11    425      start

# %% [markdown]
# # Example 3

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Validation query with ALL ROWS PER MATCH
query = """
    SELECT * FROM memory.default.employees MATCH_RECOGNIZE (
        PARTITION BY department, region
        ORDER BY hire_date
        MEASURES 
            salary AS current_salary,
            RUNNING SUM(salary) AS running_sum,
            MATCH_NUMBER() AS match_num
        ALL ROWS PER MATCH
        PATTERN (A+)
        DEFINE A AS salary > 1000
    );
    """
    
data = [
    {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]
    
output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES salary AS current_salary, RUNNING SUM(salary) AS running_sum, MATCH_NUMBER() AS match_num ALL ROWS PER MATCH PATTERN (A+) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='salary', alias='current_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='SUM(salary)', alias='running_sum', metadata={'semantics': 'RUNNING', 'explicit_semantics': True}, is_classifier=False, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'SUM(salary)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: SUM(salary)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure current_salary: salary
# DEBUG:row_match_recognize.src.executor.match_recognize:Explicit RUNNING semantics from metadata for measure running_sum: SUM(salary)
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'current_salary': 'FINAL', 'running_sum': 'RUNNING', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 5] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 5] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 3, 4, 6, 7] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [3, 5] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [1, 6, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [1, 7] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [1, 4]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 1, variable='A'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 2→2 states, 2→2 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 2 states, 2 transitions, 0.003s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0036s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 14
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=3, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 2 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 2 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=0, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 0 with FINAL semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 0 - Full variables: {'A': [0, 1]}, Running variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1200 for row 0 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 0 with RUNNING semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 0 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 0 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 1 with FINAL semantics: 1300
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 1 - Full variables: {'A': [0, 1]}, Running variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=2500 for row 1 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 1 with RUNNING semantics: 2500
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 1 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 3-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 2 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 2, included indices: [3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 1 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 3 with FINAL semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 3 - Full variables: {'A': [3]}, Running variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1100 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1100 for row 3 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 3 with RUNNING semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 2 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 3 with FINAL semantics: 2
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 3 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[3:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 3 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 3, match_number=3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.083643 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'current_salary': 1200, 'running_sum': 1200, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'current_salary': 1300, 'running_sum': 2500, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=2 to result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'current_salary': 1100, 'running_sum': 1100, 'match_num': 2, 'MATCH_NUMBER': 2, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=0 for result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'current_salary': 1200, 'running_sum': 1200, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0, '_original_order': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=1 for result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'current_salary': 1300, 'running_sum': 2500, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1, '_original_order': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=2 for result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'current_salary': 1100, 'running_sum': 1100, 'match_num': 2, 'MATCH_NUMBER': 2, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 2, '_original_order': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'current_salary' exists with values: [1200, 1300, 1100]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'running_sum' exists with values: [1200, 2500, 1100]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'match_num' exists with values: [1, 1, 2]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'current_salary', 'running_sum', 'match_num', 'salary', 'id', 'name']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=True, sort_columns=['MATCH_NUMBER', 'department', 'region', 'hire_date']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.01892685890197754, 'automata_build_time': 0.013521194458007812, 'matching_time': 0.08637452125549316, 'result_processing_time': 0.04548931121826172, 'total_time': 0.16565179824829102, 'partition_count': 1, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 7, 'total_misses': 14, 'total_compilation_time_saved': 0.3108522891998291, 'memory_used_mb': 7.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (7/21)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.311s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 7.00 MB
# Pattern value: 'A+'
# Pattern value: 'A+'
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date  current_salary  running_sum  match_num  \
# 0      Sales   West  2021-01-01            1200         1200          1
# 1      Sales   West  2021-01-02            1300         2500          1
# 2      Sales   West  2021-01-04            1100         1100          2
#
#    salary  id   name
# 0    1200   1  Alice
# 1    1300   2    Bob
# 2    1100   4  Diana

# %%
import pandas as pd
from pandas_match_recognize import match_recognize
# Use an absolute import for match_recognize.

query = """
    SELECT * FROM memory.default.employees MATCH_RECOGNIZE (
        PARTITION BY department, region
        ORDER BY hire_date
        MEASURES salary AS avg_salary
        PATTERN (A+)
        DEFINE A AS salary > 1000
    );
    """
    
data = [
        {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
        {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
        {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
        {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
    ]
    
output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES salary AS avg_salary PATTERN (A+) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='salary', alias='avg_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 1 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure avg_salary: salary
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'avg_salary': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: A+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 33.33%, Memory used: 7.00 MB, Cache size: 14/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=1, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting avg_salary to 1300 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0, 1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:avg_salary: 1300
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 3-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 2}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting avg_salary to 1100 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 2
# INFO:row_match_recognize.src.matcher.matcher:Match start: 3, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:avg_salary: 1100
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 2
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 3
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[3:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 3 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 3, match_number=3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.038314 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'avg_salary': 1300, 'MATCH_NUMBER': 1, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'department': 'Sales', 'region': 'West', 'avg_salary': 1100, 'MATCH_NUMBER': 2, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting avg_salary to 1300 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting avg_salary to 1100 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department', 'region'], ORDER BY: ['hire_date'], MEASURES: ['avg_salary']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'avg_salary']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'avg_salary']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['avg_salary']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.008233070373535156, 'automata_build_time': 0.001856088638305664, 'matching_time': 0.04080986976623535, 'result_processing_time': 0.007136106491088867, 'total_time': 0.058843135833740234, 'partition_count': 1, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 8, 'total_misses': 14, 'total_compilation_time_saved': 0.3220806121826172, 'memory_used_mb': 7.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 36.4% (8/22)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.322s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 7.00 MB
# Pattern value: 'A+'
# Pattern value: 'A+'
# DEBUG: DFA metadata keys: ['pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date  avg_salary
# 0      Sales   West  2021-01-01        1300
# 1      Sales   West  2021-01-04        1100

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Validation query with ALL ROWS PER MATCH
query = """
    SELECT * FROM memory.default.employees MATCH_RECOGNIZE (
        PARTITION BY department, region
        ORDER BY hire_date
        MEASURES 
            salary AS current_salary,
            RUNNING SUM(salary) AS running_sum,
            MATCH_NUMBER() AS match_num
        ALL ROWS PER MATCH
        PATTERN (A*)
        DEFINE A AS salary > 1000
    );
    """
    
data = [
    {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]
    
output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES salary AS current_salary, RUNNING SUM(salary) AS running_sum, MATCH_NUMBER() AS match_num ALL ROWS PER MATCH PATTERN (A*) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='salary', alias='current_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='SUM(salary)', alias='running_sum', metadata={'semantics': 'RUNNING', 'explicit_semantics': True}, is_classifier=False, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A*'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A*', metadata={'variables': ['A*'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A*'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A*
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'SUM(salary)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: SUM(salary)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure current_salary: salary
# DEBUG:row_match_recognize.src.executor.match_recognize:Explicit RUNNING semantics from metadata for measure running_sum: SUM(salary)
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'current_salary': 'FINAL', 'running_sum': 'RUNNING', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A*
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 1, 2, 3, 5, 6, 7] (iterations: 7)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [1, 2, 3, 5, 6, 7] (iterations: 6)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 3, 4, 6, 7] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [1, 3, 5, 6, 7] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [1, 6, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0006s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [1, 7] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 1] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0, 1]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0, 1]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [1, 4]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [1, 4] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 1, variable='A'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:Merging 1 equivalent state pairs
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 2→1 states, 2→1 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 2 states, 2 transitions, 0.003s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0037s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 15
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=1, measures=3, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 0 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 0, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 2 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 2 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=0, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 0 with FINAL semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 0 - Full variables: {'A': [0, 1]}, Running variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1200 for row 0 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 0 with RUNNING semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 0 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 0 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 1 with FINAL semantics: 1300
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 1 - Full variables: {'A': [0, 1]}, Running variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=2500 for row 1 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 1 with RUNNING semantics: 2500
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 1 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern only has optional components, allowing empty match
# DEBUG:row_match_recognize.src.matcher.matcher:Creating empty match at index 2 after no real match found
# DEBUG:row_match_recognize.src.matcher.matcher:Using empty match as fallback: {'start': 2, 'end': 1, 'variables': {}, 'state': 0, 'is_empty': True, 'excluded_vars': set(), 'excluded_rows': [], 'empty_pattern_rows': [2], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 2 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Added empty match row for index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Empty match, advancing from 2 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=3
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 0 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 3-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 0, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 3 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 3, included indices: [3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 1 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 3 with FINAL semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 3 - Full variables: {'A': [3]}, Running variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1100 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1100 for row 3 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 3 with RUNNING semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 3 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 3 with FINAL semantics: 3
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 3 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[3:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 3 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 3, match_number=4
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.058659 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'current_salary': 1200, 'running_sum': 1200, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'current_salary': 1300, 'running_sum': 2500, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=2 to result: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900, 'current_salary': None, 'running_sum': None, 'match_num': 2, 'MATCH_NUMBER': 2, 'IS_EMPTY_MATCH': True, '_original_row_idx': 2, '_partition_index': 0, '_partition_row_index': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=3 to result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'current_salary': 1100, 'running_sum': 1100, 'match_num': 3, 'MATCH_NUMBER': 3, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 3}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=0 for result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'current_salary': 1200, 'running_sum': 1200, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0, '_original_order': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=1 for result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'current_salary': 1300, 'running_sum': 2500, 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1, '_original_order': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=2 for result: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900, 'current_salary': None, 'running_sum': None, 'match_num': 2, 'MATCH_NUMBER': 2, 'IS_EMPTY_MATCH': True, '_original_row_idx': 2, '_partition_index': 0, '_partition_row_index': 2, '_original_order': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=3 for result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'current_salary': 1100, 'running_sum': 1100, 'match_num': 3, 'MATCH_NUMBER': 3, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 3, '_original_order': 3}
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'current_salary' exists with values: [1200, 1300, None]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'running_sum' exists with values: [1200, 2500, None]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'match_num' exists with values: [1, 1, 2]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'current_salary', 'running_sum', 'match_num', 'salary', 'id', 'name']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=True, sort_columns=['MATCH_NUMBER', 'department', 'region', 'hire_date']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.009354829788208008, 'automata_build_time': 0.012005090713500977, 'matching_time': 0.06267023086547852, 'result_processing_time': 0.012129783630371094, 'total_time': 0.09770393371582031, 'partition_count': 1, 'match_count': 3}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 8, 'total_misses': 15, 'total_compilation_time_saved': 0.3220806121826172, 'memory_used_mb': 7.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 34.8% (8/23)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.322s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 7.50 MB
# Pattern value: 'A*'
# Pattern value: 'A*'
# DEBUG: DFA metadata keys: ['allows_empty', 'pattern_variables', 'variables_with_quantifiers', 'allows_empty_match', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 0, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 0 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 0, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 0 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 0, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 0 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date current_salary running_sum  match_num  salary  \
# 0      Sales   West  2021-01-01           1200        1200          1    1200
# 1      Sales   West  2021-01-02           1300        2500          1    1300
# 2      Sales   West  2021-01-03           None        None          2     900
# 3      Sales   West  2021-01-04           1100        1100          3    1100
#
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    Diana

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Validation query with ALL ROWS PER MATCH
query = """
SELECT *
FROM memory.default.employees 
MATCH_RECOGNIZE (
  PARTITION BY department, region
  ORDER BY hire_date
  MEASURES 
    A.salary AS starting_salary,
    LAST(C.salary) AS ending_salary,
    MATCH_NUMBER() AS match_num
  ONE ROW PER MATCH
  AFTER MATCH SKIP PAST LAST ROW
  PATTERN (A B+ C+)
  DEFINE 
    A AS salary > 1000,
    B AS salary < 1000,
    C AS salary > 1000
);


    """
    
data = [
    {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]
    
output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES A.salary AS starting_salary, LAST(C.salary) AS ending_salary, MATCH_NUMBER() AS match_num ONE ROW PER MATCH AFTER MATCH SKIP PAST LAST ROW PATTERN (A B+ C+) DEFINE A AS salary > 1000, B AS salary < 1000, C AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.salary', alias='starting_salary', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(C.salary)', alias='ending_salary', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracting AFTER MATCH SKIP clause: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Extracted AFTER MATCH SKIP: AFTER MATCH SKIP PAST LAST ROW
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C+', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000'), Define(variable='B', condition='salary < 1000'), Define(variable='C', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.salary': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(C.salary)': ['C', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'B', 'C', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'C', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'C', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.salary
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(C.salary)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Pattern value: 'A B+ C+'
# Pattern value: 'A B+ C+'
# Creating transition for variable 'A' with condition: 'salary > 1000'
# Creating transition for variable 'B' with condition: 'salary < 1000'
# Creating transition for variable 'C' with condition: 'salary > 1000'
# Initialized matcher with excluded variables: set()
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
#   Evaluating condition for var: B
#     Condition failed for B
# No valid transition from state 1 at row 1
# No match found starting at index 0
# Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 3 to variable C
# Reached accepting state 3 at row 3
#   Current longest match: 1-3, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': []}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'match_number': 1}
# Evaluating expression: A.salary with RUNNING semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# DEBUG_EVAL: expr='A.salary', vars=['A', 'B', 'C'], current_idx=3, is_running=True, is_permute=False
# DEBUG_EVAL: Matched! groups: ('A', 'salary')
# DEBUG_EVAL: var_name=A, col_name=salary
# Setting starting_salary to 1300 from evaluator
# Evaluating expression: LAST(C.salary) with RUNNING semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# DEBUG_EVAL: expr='LAST(C.salary)', vars=['A', 'B', 'C'], current_idx=3, is_running=True, is_permute=False
# Setting ending_salary to 1100 from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# Setting match_num to 1 from evaluator
#
# Match information:
# Match number: 1
# Match start: 1, end: 3
# Variables: {'A': [1], 'B': [2], 'C': [3]}
#
# Result row:
# department: Sales
# region: West
# starting_salary: 1300
# ending_salary: 1100
# match_num: 1
# Find matches completed in 0.000473 seconds
# Evaluating expression: A.salary with RUNNING semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# DEBUG_EVAL: expr='A.salary', vars=['A', 'B', 'C'], current_idx=3, is_running=True, is_permute=True
# DEBUG_EVAL: Matched! groups: ('A', 'salary')
# DEBUG_EVAL: var_name=A, col_name=salary
# Setting starting_salary to 1300 from evaluator
# Evaluating expression: LAST(C.salary) with RUNNING semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# DEBUG_EVAL: expr='LAST(C.salary)', vars=['A', 'B', 'C'], current_idx=3, is_running=True, is_permute=True
# Setting ending_salary to 1100 from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [1], 'B': [2], 'C': [3]}
# Number of rows: 4
# Current index: 3
# Setting match_num to 1 from evaluator
# Query execution metrics: {'parsing_time': 0.010951042175292969, 'automata_build_time': 0.00021791458129882812, 'matching_time': 0.0019817352294921875, 'result_processing_time': 0.0003504753112792969, 'total_time': 0.013839483261108398, 'partition_count': 1, 'match_count': 1}
# Match Recognize Output:
#   department region  starting_salary  ending_salary  match_num
# 0      Sales   West             1300           1100          1

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Example query with comprehensive CLASSIFIER usage
query = """
SELECT * FROM memory.default.employees  MATCH_RECOGNIZE(
    PARTITION BY department, region
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        salary AS current_salary,
        RUNNING SUM(salary) AS running_sum
    ALL ROWS PER MATCH
    PATTERN (A C* {- B+ -} C+)
    DEFINE 
        A AS salary > 1000,
        B AS salary < 1000,
        C AS salary > 1000
);

"""

data = [
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",   "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]


output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE( PARTITION BY department, region ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, salary AS current_salary, RUNNING SUM(salary) AS running_sum ALL ROWS PER MATCH PATTERN (A C* {- B+ -} C+) DEFINE A AS salary > 1000, B AS salary < 1000, C AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='salary', alias='current_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='SUM(salary)', alias='running_sum', metadata={'semantics': 'RUNNING', 'explicit_semantics': True}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C*', 'B+', 'C+'], 'base_variables': ['A', 'C', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A C* {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A C* {- B+ -} C+', metadata={'variables': ['A', 'C*', 'B+', 'C+'], 'base_variables': ['A', 'C', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000'), Define(variable='B', condition='salary < 1000'), Define(variable='C', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'C*', 'B+', 'C+'], 'base_variables': ['A', 'C', 'B']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A C* {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'SUM(salary)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary < 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: SUM(salary)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure current_salary: salary
# DEBUG:row_match_recognize.src.executor.match_recognize:Explicit RUNNING semantics from metadata for measure running_sum: SUM(salary)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'current_salary': 'FINAL', 'running_sum': 'RUNNING'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A C* {- B+ -} C+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Processed exclusion token with variables: ['B+']
# DEBUG:row_match_recognize.src.matcher.automata:Excluded variables added to metadata: {'B'}
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=16, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 1, 2, 3] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5, 7, 8, 9, 11] (iterations: 6)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [5, 6, 8, 9, 11] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [5, 7, 8, 9, 11] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8, 9, 11] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [9, 11] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10, 14, 16] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [11] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [10, 11, 12, 13, 14, 16] (iterations: 6)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [10, 13, 14, 16] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [14] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [1, 14, 15, 17, 18] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [16] = [14, 16] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [17] = [1, 17, 18] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [18] = [1, 18] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=6, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=12, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=15, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 1] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0, 1]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0, 1]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [6]: accept=False, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [12]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 2, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [1, 15] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 4 from NFA states [1, 15]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 4, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [12] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 3, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [15] = [1, 15] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 4: added transition to 4, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 5→5 states, 8→8 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 5 states, 8 transitions, 0.008s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0096s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 16
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=True, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Exclusion handler found content: ' B+ '
# INFO:row_match_recognize.src.matcher.matcher:Using complex exclusion handler for advanced patterns
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=5, measures=3, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'C': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Found excluded variable B - will exclude row 2 from output
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned excluded row 2 to variable B (for condition evaluation)
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0], 'C': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 4 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-3, vars: ['A', 'C', 'B']
# DEBUG:row_match_recognize.src.matcher.matcher:Match contains excluded rows: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 3, 'variables': {'A': [0], 'C': [1, 3], 'B': [2]}, 'state': 4, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [2], 'has_empty_alternation': False}
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating complex exclusions for match
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating exclusion pattern: ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)
# DEBUG:row_match_recognize.src.matcher.matcher:Variables to exclude for pattern 'ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)': {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Variable B (base: B) matches exclusion pattern
# DEBUG:row_match_recognize.src.matcher.matcher:Complex exclusion: marking row 2 (var: B) for exclusion
# DEBUG:row_match_recognize.src.matcher.matcher:Updated excluded_rows: [2]
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: [2]
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: [2]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 4 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 4 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 4 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 3400 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 4 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 4500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 0 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 0: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=0, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 0 with FINAL semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 0 - Full variables: {'A': [0], 'C': [1, 3], 'B': [2]}, Running variables: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1200 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1200 for row 0 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 0 with RUNNING semantics: 1200
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 0 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 1 with FINAL semantics: C
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 1: C
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 1 with FINAL semantics: 1300
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 1 - Full variables: {'A': [0], 'C': [1, 3], 'B': [2]}, Running variables: {'A': [0], 'C': [1]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 2 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2500 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 2500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=2500 for row 1 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 1 with RUNNING semantics: 2500
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 3 with FINAL semantics: C
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 3: C
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 3 with FINAL semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 3 - Full variables: {'A': [0], 'C': [1, 3], 'B': [2]}, Running variables: {'A': [0], 'C': [1, 3], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 4500 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 4500 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=4500 for row 3 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 3 with RUNNING semantics: 4500
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 3 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:Marked excluded rows as processed: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.061212 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'pattern_var': 'A', 'current_salary': 1200, 'running_sum': 1200, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'C', 'current_salary': 1300, 'running_sum': 2500, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=2 to result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'pattern_var': 'C', 'current_salary': 1100, 'running_sum': 4500, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=0 for result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'pattern_var': 'A', 'current_salary': 1200, 'running_sum': 1200, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0, '_original_order': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=1 for result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'C', 'current_salary': 1300, 'running_sum': 2500, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1, '_original_order': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=2 for result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'pattern_var': 'C', 'current_salary': 1100, 'running_sum': 4500, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 2, '_original_order': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'pattern_var' exists with values: ['A', 'C', 'C']
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'current_salary' exists with values: [1200, 1300, 1100]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'running_sum' exists with values: [1200, 2500, 4500]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'pattern_var', 'current_salary', 'running_sum', 'salary', 'id', 'name']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=True, sort_columns=['MATCH_NUMBER', 'department', 'region', 'hire_date']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.011504411697387695, 'automata_build_time': 0.02833867073059082, 'matching_time': 0.06396746635437012, 'result_processing_time': 0.004370927810668945, 'total_time': 0.10997271537780762, 'partition_count': 1, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 8, 'total_misses': 16, 'total_compilation_time_saved': 0.3220806121826172, 'memory_used_mb': 8.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (8/24)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.322s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 8.00 MB
# Pattern value: 'A C* {- B+ -} C+'
# Pattern value: 'A C* {- B+ -} C+'
# DEBUG: DFA metadata keys: ['excluded_variables', 'allows_empty', 'pattern_variables', 'variables_with_quantifiers', 'allows_empty_match', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('C', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: C -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 3, True)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 4, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 4 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date pattern_var  current_salary  running_sum  \
# 0      Sales   West  2021-01-01           A            1200         1200
# 1      Sales   West  2021-01-02           C            1300         2500
# 2      Sales   West  2021-01-04           C            1100         4500
#
#    salary  id   name
# 0    1200   1  Alice
# 1    1300   2    Bob
# 2    1100   4  Diana

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Example query with comprehensive CLASSIFIER usage
query = """
SELECT * FROM memory.default.employees  MATCH_RECOGNIZE(
    PARTITION BY department, region
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        salary AS current_salary,
        RUNNING SUM(salary) AS running_sum
    ALL ROWS PER MATCH
    PATTERN (A {- B+ -} C+)
    DEFINE 
        A AS salary > 1000,
        B AS salary < 1000,
        C AS salary > 1000
);

"""

data = [
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",   "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]


output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE( PARTITION BY department, region ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, salary AS current_salary, RUNNING SUM(salary) AS running_sum ALL ROWS PER MATCH PATTERN (A {- B+ -} C+) DEFINE A AS salary > 1000, B AS salary < 1000, C AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='salary', alias='current_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='SUM(salary)', alias='running_sum', metadata={'semantics': 'RUNNING', 'explicit_semantics': True}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A {- B+ -} C+', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000'), Define(variable='B', condition='salary < 1000'), Define(variable='C', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'SUM(salary)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary < 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: SUM(salary)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 3 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:Mixed semantics query: FINAL default for measure current_salary: salary
# DEBUG:row_match_recognize.src.executor.match_recognize:Explicit RUNNING semantics from metadata for measure running_sum: SUM(salary)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'current_salary': 'FINAL', 'running_sum': 'RUNNING'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: A {- B+ -} C+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Processed exclusion token with variables: ['B+']
# DEBUG:row_match_recognize.src.matcher.automata:Excluded variables added to metadata: {'B'}
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=12, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4, 5, 7] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [5, 7] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [6, 10, 12] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [7] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [6, 7, 8, 9, 10, 12] (iterations: 6)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [9] = [6, 9, 10, 12] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [10] = [10] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 10, 11, 13, 14] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [12] = [10, 12] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [13] = [1, 13, 14] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [14] = [1, 14] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=4, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='B', target=8, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='C', target=11, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [4]: accept=False, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 2 from NFA states [8]: accept=False, variables={'B'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 3 from NFA states [1, 11]: accept=True, variables={'C'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 3, variable='C'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [8] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 2: added transition to 2, variable='B'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [11] = [1, 11] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 3: added transition to 3, variable='C'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 4→4 states, 5→5 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 4 states, 5 transitions, 0.007s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0075s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 17
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=True, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Exclusion handler found content: ' B+ '
# INFO:row_match_recognize.src.matcher.matcher:Using complex exclusion handler for advanced patterns
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=4, measures=3, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Found excluded variable B - will exclude row 2 from output
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned excluded row 2 to variable B (for condition evaluation)
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 3 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-3, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Match contains excluded rows: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [2], 'has_empty_alternation': False}
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating complex exclusions for match
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating exclusion pattern: ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)
# DEBUG:row_match_recognize.src.matcher.matcher:Variables to exclude for pattern 'ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)': {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Variable B (base: B) matches exclusion pattern
# DEBUG:row_match_recognize.src.matcher.matcher:Complex exclusion: marking row 2 (var: B) for exclusion
# DEBUG:row_match_recognize.src.matcher.matcher:Updated excluded_rows: [2]
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: [2]
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: [2]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 2200 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 3 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 3300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 1 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 1: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=1, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 1 with FINAL semantics: 1300
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 1 - Full variables: {'A': [1], 'B': [2], 'C': [3]}, Running variables: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 1 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 1300 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 1300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=1300 for row 1 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 1 with RUNNING semantics: 1300
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 3 with FINAL semantics: C
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 3: C
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'current_salary' = 'salary' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure current_salary for row 3 with FINAL semantics: 1100
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'running_sum' = 'SUM(salary)' using RUNNING semantics
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Row 3 - Full variables: {'A': [1], 'B': [2], 'C': [3]}, Running variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 3300 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 3300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:DEBUG: Set running_sum=3300 for row 3 with RUNNING semantics (using running context for complex navigation)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure running_sum for row 3 with RUNNING semantics: 3300
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 3 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:Marked excluded rows as processed: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.074074 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'A', 'current_salary': 1300, 'running_sum': 1300, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'pattern_var': 'C', 'current_salary': 1100, 'running_sum': 3300, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=0 for result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'A', 'current_salary': 1300, 'running_sum': 1300, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 0, '_original_order': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=1 for result: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100, 'pattern_var': 'C', 'current_salary': 1100, 'running_sum': 3300, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 1, '_original_order': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'pattern_var' exists with values: ['A', 'C']
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'current_salary' exists with values: [1300, 1100]
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'running_sum' exists with values: [1300, 3300]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'pattern_var', 'current_salary', 'running_sum', 'salary', 'id', 'name']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=True, sort_columns=['MATCH_NUMBER', 'department', 'region', 'hire_date']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.01248931884765625, 'automata_build_time': 0.024169445037841797, 'matching_time': 0.07757091522216797, 'result_processing_time': 0.0049173831939697266, 'total_time': 0.12111902236938477, 'partition_count': 1, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 8, 'total_misses': 17, 'total_compilation_time_saved': 0.3220806121826172, 'memory_used_mb': 8.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 32.0% (8/25)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.322s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 8.50 MB
# Pattern value: 'A {- B+ -} C+'
# Pattern value: 'A {- B+ -} C+'
# DEBUG: DFA metadata keys: ['excluded_variables', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, True)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 3 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date pattern_var  current_salary  running_sum  \
# 0      Sales   West  2021-01-02           A            1300         1300
# 1      Sales   West  2021-01-04           C            1100         3300
#
#    salary  id   name
# 0    1300   2    Bob
# 1    1100   4  Diana

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Example query with comprehensive CLASSIFIER usage
query = """
SELECT * FROM  memory.default.employees MATCH_RECOGNIZE(
    PARTITION BY department, region
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        CLASSIFIER(A) AS is_a_var,
        CLASSIFIER(C) AS is_c_var,
        salary AS current_salary,
        RUNNING SUM(salary) AS running_sum
    ONE ROW PER MATCH
    PATTERN (A {- B+ -} C+)
    DEFINE 
        A AS salary > 1000,
        B AS salary < 1000,
        C AS salary > 1000
);
"""

data = [
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",   "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]


output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE( PARTITION BY department, region ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, CLASSIFIER(A) AS is_a_var, CLASSIFIER(C) AS is_c_var, salary AS current_salary, RUNNING SUM(salary) AS running_sum ONE ROW PER MATCH PATTERN (A {- B+ -} C+) DEFINE A AS salary > 1000, B AS salary < 1000, C AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='CLASSIFIER(A)', alias='is_a_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='CLASSIFIER(C)', alias='is_c_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='salary', alias='current_salary', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=False), Measure(expression='SUM(salary)', alias='running_sum', metadata={'semantics': 'RUNNING', 'explicit_semantics': True}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A {- B+ -} C+', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000'), Define(variable='B', condition='salary < 1000'), Define(variable='C', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A {- B+ -} C+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER(A)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER(C)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'SUM(salary)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary < 1000': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER(A)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER(C)
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: salary
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: SUM(salary)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 5 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure is_a_var: CLASSIFIER(A)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure is_c_var: CLASSIFIER(C)
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure current_salary: salary
# DEBUG:row_match_recognize.src.executor.match_recognize:Explicit RUNNING semantics from metadata for measure running_sum: SUM(salary)
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'is_a_var': 'FINAL', 'is_c_var': 'FINAL', 'current_salary': 'FINAL', 'running_sum': 'RUNNING'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: A {- B+ -} C+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 32.00%, Memory used: 8.50 MB, Cache size: 17/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=True, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Exclusion handler found content: ' B+ '
# INFO:row_match_recognize.src.matcher.matcher:Using complex exclusion handler for advanced patterns
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=4, measures=5, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 3 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for C: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Found excluded variable B - will exclude row 2 from output
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned excluded row 2 to variable B (for condition evaluation)
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  Variable B marked as excluded in transition metadata
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: C
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=C)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for C
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was C)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition C: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable C
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 3 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-3, vars: ['A', 'B', 'C']
# DEBUG:row_match_recognize.src.matcher.matcher:Match contains excluded rows: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [2], 'has_empty_alternation': False}
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating complex exclusions for match
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluating exclusion pattern: ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)
# DEBUG:row_match_recognize.src.matcher.matcher:Variables to exclude for pattern 'ExclusionNode(node_type=<ExclusionNodeType.VARIABLE: 'VARIABLE'>, value='B', quantifier='+', children=[], is_negated=False)': {'B'}
# DEBUG:row_match_recognize.src.matcher.matcher:Variable B (base: B) matches exclusion pattern
# DEBUG:row_match_recognize.src.matcher.matcher:Complex exclusion: marking row 2 (var: B) for exclusion
# DEBUG:row_match_recognize.src.matcher.matcher:Updated excluded_rows: [2]
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 3, 'variables': {'A': [1], 'B': [2], 'C': [3]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [2], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER(A)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER(A)': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER(A)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER(A) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting is_a_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER(C)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER(C)': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER(C)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER(C) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting is_c_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=False
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting current_salary to 1100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 3300 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 3300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting running_sum to 3300 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [1], 'B': [2], 'C': [3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: C
# INFO:row_match_recognize.src.matcher.matcher:is_a_var: A
# INFO:row_match_recognize.src.matcher.matcher:is_c_var: C
# INFO:row_match_recognize.src.matcher.matcher:current_salary: 1100
# INFO:row_match_recognize.src.matcher.matcher:running_sum: 3300
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:Marked excluded rows as processed: [2]
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.061391 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'pattern_var': 'C', 'is_a_var': 'A', 'is_c_var': 'C', 'current_salary': 1100, 'running_sum': 3300, 'MATCH_NUMBER': 1, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER(A)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER(A)': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER(A)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER(A) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting is_a_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER(C)', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER(C)': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER(C)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER(C) with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: C (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting is_c_var to C from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'salary', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'salary': None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Expression doesn't match pure aggregate pattern: salary
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: salary
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: salary with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2], 'C': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating pattern variable reference: salary, current_idx=3, is_running=False, is_permute=True
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Preprocessed expression: 'salary' -> 'salary'
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1100 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting current_salary to 1100 from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'SUM(salary)', semantics: 'RUNNING'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'SUM(salary)': <re.Match object; span=(0, 4), match='SUM('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: SUM, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Using production aggregate evaluator for: SUM(salary) -> SUM
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Initialized ProductionAggregateEvaluator with context containing 4 rows and 3 variables
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Parsed aggregate function SUM with args: ['salary']
# DEBUG:row_match_recognize.src.matcher.production_aggregates:PROD_AGG_FINAL: evaluate_aggregate returning: 3300 (type: <class 'int'>)
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Production aggregate result for SUM(salary): 3300 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting running_sum to 3300 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department', 'region'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'is_a_var', 'is_c_var', 'current_salary', 'running_sum']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'region', 'hire_date', 'pattern_var', 'is_a_var', 'is_c_var', 'current_salary', 'running_sum']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'is_a_var', 'is_c_var', 'current_salary', 'running_sum']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'is_a_var', 'is_c_var', 'current_salary', 'running_sum']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.015215635299682617, 'automata_build_time': 0.0018887519836425781, 'matching_time': 0.0641927719116211, 'result_processing_time': 0.01757216453552246, 'total_time': 0.10117149353027344, 'partition_count': 1, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 9, 'total_misses': 17, 'total_compilation_time_saved': 0.34470248222351074, 'memory_used_mb': 8.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 34.6% (9/26)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.345s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 8.50 MB
# Pattern value: 'A {- B+ -} C+'
# Pattern value: 'A {- B+ -} C+'
# DEBUG: DFA metadata keys: ['excluded_variables', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, True)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['C']
# DEBUG: Categorized transitions: {'accepting': [('C', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: C -> state 3 (alternation priority: N/A)
# Match Recognize Output:
#   department region   hire_date pattern_var is_a_var is_c_var  current_salary  \
# 0      Sales   West  2021-01-02           C        A        C            1100
#
#    running_sum
# 0         3300

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Example query with comprehensive CLASSIFIER usage
query = """
SELECT * FROM memory.default.employees MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ONE ROW PER MATCH
    PATTERN (^A+)
    DEFINE 
        A AS salary > 1000
);
"""

data = [
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",   "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
]


output_df = match_recognize(query, pd.DataFrame(data))
print("Match Recognize Output:")
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employees MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ONE ROW PER MATCH PATTERN (^A+) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='^A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache MISS for pattern: ^A+
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0, 2, 3, 4, 6] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [1] = [1] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [2] = [2, 3, 4, 6] (iterations: 4)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [3] = [3, 4, 6] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0005s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [4] = [4] (iterations: 1)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [1, 4, 5, 7, 8] (iterations: 5)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0004s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [6] = [4, 6] (iterations: 2)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [7] = [1, 7, 8] (iterations: 3)
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0003s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [8] = [1, 8] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.automata:Added transition: variable='A', target=5, priority=0
# DEBUG:row_match_recognize.src.matcher.automata:Added epsilon transition to state 1 with priority 0
# DEBUG:row_match_recognize.src.matcher.dfa:[DFA_ENHANCED] Initialized DFA builder with limits: states=10000, subset_size=50
# DEBUG:row_match_recognize.performance:Starting dfa_build
# INFO:row_match_recognize.src.matcher.dfa:Starting DFA construction from NFA
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [0] = [0] (iterations: 1)
# DEBUG:row_match_recognize.src.matcher.dfa:Start state epsilon closure: [0]
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 0 from NFA states [0]: accept=False, variables={'A'}, anchor=True
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0001s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [1, 5] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:Created DFA state 1 from NFA states [1, 5]: accept=True, variables={'A'}, anchor=False
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 0: added transition to 1, variable='A'
# DEBUG:row_match_recognize.performance:Starting epsilon_closure
# INFO:row_match_recognize.performance:epsilon_closure completed in 0.0002s
# DEBUG:row_match_recognize.src.matcher.automata:Epsilon closure of [5] = [1, 5] (iterations: 2)
# DEBUG:row_match_recognize.src.matcher.dfa:DFA state 1: added transition to 1, variable='A'
# INFO:row_match_recognize.src.matcher.dfa:Applying DFA optimizations...
# INFO:row_match_recognize.src.matcher.dfa:Optimizing DFA...
# INFO:row_match_recognize.src.matcher.dfa:DFA optimization completed in 0.000s: 2→2 states, 2→2 transitions
# INFO:row_match_recognize.src.matcher.dfa:DFA construction completed: 2 states, 2 transitions, 0.003s
# INFO:row_match_recognize.performance:dfa_build completed in 0.0041s
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache size after adding new pattern: 18
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0, 1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.027698 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.00874471664428711, 'automata_build_time': 0.01331186294555664, 'matching_time': 0.029919862747192383, 'result_processing_time': 0.006811857223510742, 'total_time': 0.059860944747924805, 'partition_count': 1, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 9, 'total_misses': 18, 'total_compilation_time_saved': 0.34470248222351074, 'memory_used_mb': 9.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 33.3% (9/27)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.345s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 9.00 MB
# Pattern value: '^A+'
# Pattern value: '^A+'
# DEBUG: DFA metadata keys: ['has_start_anchor', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# Match Recognize Output:
#   department   hire_date pattern_var  match_num
# 0      Sales  2021-01-01           A          1

# %% [markdown]
# # Example 4

# %%
import pandas as pd
from pandas_match_recognize import match_recognize

# Create test data with different departments to test partition behavior
data = [
    # Sales department - First row has high salary
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob",   "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
    
    # Marketing department - Last row has high salary
    {"id": 5, "name": "Eve", "department": "Marketing", "region": "East", "hire_date": "2021-01-01", "salary": 900},
    {"id": 6, "name": "Frank", "department": "Marketing", "region": "East", "hire_date": "2021-01-02", "salary": 950},
    {"id": 7, "name": "Grace", "department": "Marketing", "region": "East", "hire_date": "2021-01-03", "salary": 980},
    {"id": 8, "name": "Henry", "department": "Marketing", "region": "East", "hire_date": "2021-01-04", "salary": 1200},
    
    # IT department - All rows have high salary
    {"id": 9, "name": "Ivy", "department": "IT", "region": "North", "hire_date": "2021-01-01", "salary": 1500},
    {"id": 10, "name": "Jack", "department": "IT", "region": "North", "hire_date": "2021-01-02", "salary": 1600},
    {"id": 11, "name": "Kate", "department": "IT", "region": "North", "hire_date": "2021-01-03", "salary": 1700},
    {"id": 12, "name": "Leo", "department": "IT", "region": "North", "hire_date": "2021-01-04", "salary": 1800},
    
    # HR department - No rows have high salary
    {"id": 13, "name": "Mike", "department": "HR", "region": "South", "hire_date": "2021-01-01", "salary": 950},
    {"id": 14, "name": "Nina", "department": "HR", "region": "South", "hire_date": "2021-01-02", "salary": 980},
    {"id": 15, "name": "Oscar", "department": "HR", "region": "South", "hire_date": "2021-01-03", "salary": 990},
    {"id": 16, "name": "Pam", "department": "HR", "region": "South", "hire_date": "2021-01-04", "salary": 995},
]

df = pd.DataFrame(data)

print("Testing Pattern Anchors\n")

# Test 1: Start anchor (^) - Should match patterns starting at the beginning of a partition
query_start_anchor = """
SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ONE ROW PER MATCH
    PATTERN (^A+)
    DEFINE 
        A AS salary > 1000
);
"""

print("Test 1: Start Anchor (^) - Should only match departments where first employee has salary > 1000")
output_df = match_recognize(query_start_anchor, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ONE ROW PER MATCH PATTERN (^A+) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='^A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: ^A+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 33.33%, Memory used: 9.00 MB, Cache size: 18/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 1
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0, 1]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.046904 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.017944 seconds
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1500
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1500 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1600
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1600 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1700
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1700 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1, 2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1800
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1800 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 3, 'variables': {'A': [0, 1, 2, 3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 3, 'variables': {'A': [0, 1, 2, 3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0, 1, 2, 3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: IT
# INFO:row_match_recognize.src.matcher.matcher:region: North
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.034585 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=2, row_idx=0 to result: {'department': 'IT', 'region': 'North', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 0, '_partition_index': 2, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.017271 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.009644746780395508, 'automata_build_time': 0.0013849735260009766, 'matching_time': 0.12205052375793457, 'result_processing_time': 0.010886192321777344, 'total_time': 0.14531612396240234, 'partition_count': 4, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 10, 'total_misses': 18, 'total_compilation_time_saved': 0.3570442199707031, 'memory_used_mb': 9.0}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 35.7% (10/28)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.357s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 9.00 MB
# Testing Pattern Anchors
#
# Test 1: Start Anchor (^) - Should only match departments where first employee has salary > 1000
# Pattern value: '^A+'
# Pattern value: '^A+'
# DEBUG: DFA metadata keys: ['has_start_anchor', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
#   department   hire_date pattern_var  match_num
# 0      Sales  2021-01-01           A          1
# 1         IT  2021-01-01           A          1

# %%
# Test 2: End anchor ($) - Should match patterns ending at the end of a partition
query_end_anchor = """
SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ONE ROW PER MATCH
    PATTERN (A+$)
    DEFINE 
        A AS salary > 1000
);
"""

print("Test 2: End Anchor ($) - Should only match departments where last employee has salary > 1000")
output_df = match_recognize(query_end_anchor, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ONE ROW PER MATCH PATTERN (A+$) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+$
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+$', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+$
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: A+$
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 36.36%, Memory used: 10.50 MB, Cache size: 21/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=0 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=1 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor requires match to end at last row, but we're at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=1 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor requires match to end at last row, but we're at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 3-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor for match ending at row 3, partition ends at 3
# DEBUG:row_match_recognize.src.matcher.matcher:Match correctly ends at last row for $ pattern, accepting
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 3, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 3
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[3:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 3 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 4, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.040107 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 3, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 980
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 980 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 8, 'name': 'Henry', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-04', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 8, 'name': 'Henry', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-04', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 3-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Checking end anchor for match ending at row 3, partition ends at 3
# DEBUG:row_match_recognize.src.matcher.matcher:Match correctly ends at last row for $ pattern, accepting
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 3, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Marketing
# INFO:row_match_recognize.src.matcher.matcher:region: East
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 3
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[3:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 3 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 4, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.035709 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=1, row_idx=0 to result: {'department': 'Marketing', 'region': 'East', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 3, '_partition_index': 1, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': True, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1500
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), right=1000 (<class 'int'>)
# ...
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.021881 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [7]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 7
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.008698463439941406, 'automata_build_time': 0.0012624263763427734, 'matching_time': 0.12937116622924805, 'result_processing_time': 0.016993284225463867, 'total_time': 0.15737223625183105, 'partition_count': 4, 'match_count': 3}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 14, 'total_misses': 21, 'total_compilation_time_saved': 0.4195549488067627, 'memory_used_mb': 10.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 40.0% (14/35)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.420s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 10.50 MB
# Test 2: End Anchor ($) - Should only match departments where last employee has salary > 1000
# Pattern value: 'A+$'
# Pattern value: 'A+$'
# DEBUG: DFA metadata keys: ['has_end_anchor', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
#   department   hire_date pattern_var  match_num
# 0      Sales  2021-01-04           A          1
# 1  Marketing  2021-01-04           A          1
# 2         IT  2021-01-01           A          1

# %%
# Test 3: Both anchors (^$) - Should match patterns spanning the entire partition
query_both_anchors = """
SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ONE ROW PER MATCH
    PATTERN (^A+$)
    DEFINE 
        A AS salary > 1000
);
"""

print("Test 3: Both Anchors (^$) - Should only match departments where ALL employees have salary > 1000")
output_df = match_recognize(query_both_anchors, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ONE ROW PER MATCH PATTERN (^A+$) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+$
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='^A+$', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+$
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: ^A+$
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 36.36%, Memory used: 10.50 MB, Cache size: 21/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=True
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': True, 'spans_partition': True, 'start_anchor_states': {0}, 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=0 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=1 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern has both anchors but we're not at the end of partition
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.030503 seconds
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=True
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': True, 'spans_partition': True, 'start_anchor_states': {0}, 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.019704 seconds
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=True
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': True, 'spans_partition': True, 'start_anchor_states': {0}, 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1500
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1500 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=0 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1600
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1600 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=1 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1700
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1700 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor failed: row_idx=2 is not at partition end (expected 3)
# DEBUG:row_match_recognize.src.matcher.matcher:End anchor check failed for accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1, 2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1800
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1800 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found complete match spanning entire partition
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 3, 'variables': {'A': [0, 1, 2, 3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 0, 'end': 3, 'variables': {'A': [0, 1, 2, 3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 3
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 0, end: 3
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [0, 1, 2, 3]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: IT
# INFO:row_match_recognize.src.matcher.matcher:region: North
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: A
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 0
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:3]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 4
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 4
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 4
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.035363 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=2, row_idx=0 to result: {'department': 'IT', 'region': 'North', 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 0, '_partition_index': 2, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=True, has_both_anchors=True
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': True, 'spans_partition': True, 'start_anchor_states': {0}, 'end_anchor_accepting_states': {1}}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.014800 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to A from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [8, 9, 10, 11]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 11
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.010957956314086914, 'automata_build_time': 0.0010120868682861328, 'matching_time': 0.10706090927124023, 'result_processing_time': 0.005654335021972656, 'total_time': 0.12569689750671387, 'partition_count': 4, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 15, 'total_misses': 21, 'total_compilation_time_saved': 0.43152499198913574, 'memory_used_mb': 10.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 41.7% (15/36)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.432s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 10.50 MB
# Test 3: Both Anchors (^$) - Should only match departments where ALL employees have salary > 1000
# Pattern value: '^A+$'
# Pattern value: '^A+$'
# DEBUG: DFA metadata keys: ['has_start_anchor', 'has_end_anchor', 'spans_partition', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
#   department   hire_date pattern_var  match_num
# 0         IT  2021-01-01           A          1

# %%
# Test 4: Start anchor with ALL ROWS PER MATCH to see the actual matched rows
query_start_all_rows = """
SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ALL ROWS PER MATCH
    PATTERN (^A+)
    DEFINE 
        A AS salary > 1000
);
"""

print("Test 4: Start Anchor (^) with ALL ROWS PER MATCH - Shows matched rows")
output_df = match_recognize(query_start_all_rows, df)
print(output_df)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ALL ROWS PER MATCH PATTERN (^A+) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='^A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0003s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ^A+
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted pattern variables from DEFINE condition 'salary > 1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced pattern variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset union variables: set()
# DEBUG:src.parser.match_recognize_extractor:Subset components: set()
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:Other function: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:Other function: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: ^A+
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 36.36%, Memory used: 10.50 MB, Cache size: 21/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=False, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=2, measures=2, permute=False
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 1, 'variables': {'A': [0, 1]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1]
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 0 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 0: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 0 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 0 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 1 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 1: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 1 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[0:1]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 2
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 0 to 2
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 2
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 1, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.043488 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=1 to result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.020926 seconds
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=True, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1500
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1500 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1500 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-0, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1600
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1600 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1600 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-1, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1700
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1700 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1700 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-2, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [0, 1, 2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1800
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1800 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1800 Gt 1000 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 1 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 0-3, vars: ['A']
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 0, 'end': 3, 'variables': {'A': [0, 1, 2, 3]}, 'state': 1, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1 with ALL ROWS PER MATCH
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded variables: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Excluded rows: []
# INFO:row_match_recognize.src.matcher.matcher:Processing match 1, included indices: [0, 1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Regular pattern: using range [0, 1, 2, 3]
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 0 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 0: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 0: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 0
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 0 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 0 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 1 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 1: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 1: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 1
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 1 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 1 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 2: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: A (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure pattern_var for row 2 with FINAL semantics: A
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated CLASSIFIER() for row 2: A
# DEBUG:row_match_recognize.src.matcher.matcher:Row 2: Measure 'match_num' = 'MATCH_NUMBER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [0, 1, 2, 3]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Evaluated measure match_num for row 2 with FINAL semantics: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Added row 2 to results
# DEBUG:row_match_recognize.src.matcher.matcher:Row 3: Measure 'pattern_var' = 'CLASSIFIER()' using FINAL semantics
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# ...
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': True, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': {0}, 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 13, 'name': 'Mike', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-01', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1000 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=1 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=2 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 1 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Start anchor failed: row_idx=3 is not at partition start
# DEBUG:row_match_recognize.src.matcher.matcher:Start state anchor check failed at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.015724 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=0 for result: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 0, '_partition_row_index': 0, '_original_order': 0}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=0, row_idx=1 for result: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 1, '_original_order': 1}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=2, row_idx=0 for result: {'id': 9, 'name': 'Ivy', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-01', 'salary': 1500, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 0, '_partition_index': 2, '_partition_row_index': 0, '_original_order': 2}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=2, row_idx=1 for result: {'id': 10, 'name': 'Jack', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-02', 'salary': 1600, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 1, '_partition_index': 2, '_partition_row_index': 1, '_original_order': 3}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=2, row_idx=2 for result: {'id': 11, 'name': 'Kate', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-03', 'salary': 1700, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 2, '_partition_index': 2, '_partition_row_index': 2, '_original_order': 4}
# DEBUG:row_match_recognize.src.executor.match_recognize:Using partition sort key: partition_idx=2, row_idx=3 for result: {'id': 12, 'name': 'Leo', 'department': 'IT', 'region': 'North', 'hire_date': '2021-01-04', 'salary': 1800, 'pattern_var': 'A', 'match_num': 1, 'MATCH_NUMBER': 1, 'IS_EMPTY_MATCH': False, '_original_row_idx': 3, '_partition_index': 2, '_partition_row_index': 3, '_original_order': 5}
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * detected - keeping all columns
# DEBUG:row_match_recognize.src.executor.match_recognize:Checking measure columns in final DataFrame:
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'pattern_var' exists with values: ['A', 'A', 'A']
# DEBUG:row_match_recognize.src.executor.match_recognize:  Measure 'match_num' exists with values: [1, 1, 1]
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num', 'salary', 'id', 'region', 'name']
# DEBUG:row_match_recognize.src.executor.match_recognize:Final sort decision: partition_by=True, used_partition_sorting=True, sort_columns=['MATCH_NUMBER', 'department', 'hire_date']
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.01060175895690918, 'automata_build_time': 0.001543283462524414, 'matching_time': 0.1366739273071289, 'result_processing_time': 0.006148338317871094, 'total_time': 0.15784597396850586, 'partition_count': 4, 'match_count': 2}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 16, 'total_misses': 21, 'total_compilation_time_saved': 0.4438667297363281, 'memory_used_mb': 10.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 43.2% (16/37)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.444s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 10.50 MB
# Test 4: Start Anchor (^) with ALL ROWS PER MATCH - Shows matched rows
# Pattern value: '^A+'
# Pattern value: '^A+'
# DEBUG: DFA metadata keys: ['has_start_anchor', 'pattern_variables', 'variables_with_quantifiers', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: False
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [('A', 1, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
#   department   hire_date pattern_var  match_num  salary  id region   name
# 0      Sales  2021-01-01           A          1    1200   1   West  Alice
# 1      Sales  2021-01-02           A          1    1300   2   West    Bob
# 2         IT  2021-01-01           A          1    1500   9  North    Ivy
# 3         IT  2021-01-02           A          1    1600  10  North   Jack
# 4         IT  2021-01-03           A          1    1700  11  North   Kate
# 5         IT  2021-01-04           A          1    1800  12  North    Leo

# %%
# Test PERMUTE functionality
query_permute = """
SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE(
    PARTITION BY department
    ORDER BY hire_date
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B))
    DEFINE 
        A AS salary > 1200,
        B AS salary < 1000
);
"""

print("Test PERMUTE - Should match both orderings of A and B")
output_df = match_recognize(query_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.employee_data MATCH_RECOGNIZE( PARTITION BY department ORDER BY hire_date MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num ONE ROW PER MATCH PATTERN (PERMUTE(A, B)) DEFINE A AS salary > 1200, B AS salary < 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'FINAL', 'explicit_semantics': False}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B'], 'base_variables': ['A', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B)', metadata={'variables': ['A', 'B'], 'base_variables': ['A', 'B'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1200'), Define(variable='B', condition='salary < 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B'], 'base_variables': ['A', 'B'], 'permute': True, 'nested_permute': False}
# DEBUG:row_match_recognize.performance:Starting pattern_tokenization
# INFO:row_match_recognize.performance:pattern_tokenization completed in 0.0002s
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:No specific function validation needed for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:row_match_recognize.src.executor.match_recognize:Determining measure semantics for 2 measures
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure pattern_var: CLASSIFIER()
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW mode: FINAL semantics for measure match_num: MATCH_NUMBER()
# INFO:row_match_recognize.src.executor.match_recognize:Final measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL'}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern compilation cache HIT for pattern: PERMUTE(A, B)
# DEBUG:row_match_recognize.src.executor.match_recognize:Cache efficiency: 36.36%, Memory used: 10.50 MB, Cache size: 21/10000
# DEBUG:row_match_recognize.src.matcher.matcher:Pattern analysis: permute=True, alternations=False, exclusions=False, quantifiers=False
# DEBUG:row_match_recognize.src.matcher.matcher:Matcher configuration validated successfully
# INFO:row_match_recognize.src.matcher.matcher:EnhancedMatcher initialized: states=5, measures=2, permute=True
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 0
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Gt 1200 = True (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1300
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1300 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1300 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition A: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable A
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=True, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Reached accepting state 3 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:  Updated longest match: 1-2, vars: ['A', 'B']
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from accepting state 3 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:Found non-empty match: {'start': 1, 'end': 2, 'variables': {'A': [1], 'B': [2]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False}
# INFO:row_match_recognize.src.matcher.matcher:
# Processing match with ONE ROW PER MATCH:
# INFO:row_match_recognize.src.matcher.matcher:Match: {'start': 1, 'end': 2, 'variables': {'A': [1], 'B': [2]}, 'state': 3, 'is_empty': False, 'excluded_vars': set(), 'excluded_rows': [], 'has_empty_alternation': False, 'match_number': 1}
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 4
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.matcher.matcher:Setting match_num to 1 from evaluator
# INFO:row_match_recognize.src.matcher.matcher:
# Match information:
# INFO:row_match_recognize.src.matcher.matcher:Match number: 1
# INFO:row_match_recognize.src.matcher.matcher:Match start: 1, end: 2
# INFO:row_match_recognize.src.matcher.matcher:Variables: {'A': [1], 'B': [2]}
# INFO:row_match_recognize.src.matcher.matcher:
# Result row:
# INFO:row_match_recognize.src.matcher.matcher:department: Sales
# INFO:row_match_recognize.src.matcher.matcher:region: West
# INFO:row_match_recognize.src.matcher.matcher:pattern_var: B
# INFO:row_match_recognize.src.matcher.matcher:match_num: 1
# INFO:row_match_recognize.src.matcher.matcher:MATCH_NUMBER: 1
# INFO:row_match_recognize.src.matcher.matcher:_original_row_idx: 1
# DEBUG:row_match_recognize.src.matcher.matcher:Calculating skip position: mode=SkipMode.PAST_LAST_ROW, skip_var=None, match_range=[1:2]
# DEBUG:row_match_recognize.src.matcher.matcher:PAST_LAST_ROW: skipping to position 3
# DEBUG:row_match_recognize.src.matcher.matcher:Non-empty match, advancing from 1 to 3
# DEBUG:row_match_recognize.src.matcher.matcher:SKIP PAST LAST ROW: continuing search from position 3
# DEBUG:row_match_recognize.src.matcher.matcher:End of iteration 2, match_number=2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1100
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1100 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1100 Lt 1000 = False (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 0 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.039423 seconds
# DEBUG:row_match_recognize.src.executor.match_recognize:Added partition tracking: partition_idx=0, row_idx=0 to result: {'department': 'Sales', 'region': 'West', 'pattern_var': 'B', 'match_num': 1, 'MATCH_NUMBER': 1, '_original_row_idx': 1, '_partition_index': 0, '_partition_row_index': 0}
# INFO:row_match_recognize.src.matcher.matcher:Starting find_matches with 4 rows
# INFO:row_match_recognize.src.matcher.matcher:Find matches with all_rows=False, show_empty=True, include_unmatched=False
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 1, start_idx=0
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 5, 'name': 'Eve', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 900}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 900
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=900 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 900 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 0 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [0]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 2 at row 1
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 0
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 2, start_idx=1
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 1, data: {'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-02', 'salary': 950}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 950
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=950 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 950 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 1 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [1]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 980
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 980 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 2 at row 2
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 1
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 3, start_idx=2
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.matcher:DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG:row_match_recognize.src.matcher.matcher:Has permute flag: True
# DEBUG:row_match_recognize.src.matcher.matcher:Has alternations flag: False
# DEBUG:row_match_recognize.src.matcher.matcher:Final has_alternations result: False
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Checking complex back-references for 2 conditions
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for A: salary > 1200
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 2, data: {'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 980
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 980 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 7, 'name': 'Grace', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-03', 'salary': 980}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 980
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=980 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 980 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 2 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 8, 'name': 'Henry', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-04', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {'B': [2]}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 8, 'name': 'Henry', 'department': 'Marketing', 'region': 'East', 'hire_date': '2021-01-04', 'salary': 1200}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 1200
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=1200 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 1200 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:No valid transition from state 2 at row 3
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 2
# DEBUG:row_match_recognize.src.matcher.matcher:Iteration 4, start_idx=3
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# ...
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Analyzing condition for B: salary < 1000
# DEBUG:row_match_recognize.src.matcher.matcher:  Referenced vars: set()
# DEBUG:row_match_recognize.src.matcher.matcher:Summary: has_nav_functions=False, cross_var_dependencies=False, has_classifier_subset_refs=False
# DEBUG:row_match_recognize.src.matcher.matcher:No complex back-references detected
# DEBUG:row_match_recognize.src.matcher.matcher:Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# DEBUG:row_match_recognize.src.matcher.matcher:Anchor metadata: has_end_anchor=False, has_both_anchors=False
# DEBUG:row_match_recognize.src.matcher.matcher:Full anchor metadata: {'has_start_anchor': False, 'has_end_anchor': False, 'spans_partition': False, 'start_anchor_states': set(), 'end_anchor_accepting_states': set()}
# DEBUG:row_match_recognize.src.matcher.matcher:Testing row 3, data: {'id': 16, 'name': 'Pam', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-04', 'salary': 995}
# DEBUG:row_match_recognize.src.matcher.matcher:  Current var_assignments: {}
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: A
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 16, 'name': 'Pam', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-04', 'salary': 995}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 995
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=995 (<class 'int'>), op=Gt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=995 (<class 'int'>), right=1200 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 995 Gt 1200 = False (evaluating for var=A)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition failed for A
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=False, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was A)
# DEBUG:row_match_recognize.src.matcher.matcher:  Evaluating condition for var: B
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Set context.current_var = B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: Calling condition function with row={'id': 16, 'name': 'Pam', 'department': 'HR', 'region': 'South', 'hire_date': '2021-01-04', 'salary': 995}
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:Universal pattern variable 'salary' resolved to: 995
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=995 (<class 'int'>), op=Lt
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE: left=995 (<class 'int'>), right=1000 (<class 'int'>)
# DEBUG:row_match_recognize.src.matcher.condition_evaluator:[DEBUG] COMPARE RESULT: 995 Lt 1000 = True (evaluating for var=B)
# DEBUG:row_match_recognize.src.matcher.matcher:    Condition passed for B
# DEBUG:row_match_recognize.src.matcher.matcher:    DEBUG: condition result=True, type=<class 'bool'>
# DEBUG:row_match_recognize.src.matcher.matcher:  [DEBUG] Clearing context.current_var (was B)
# DEBUG:row_match_recognize.src.matcher.matcher:  Transition B: accepting=False, has_back_ref=False, is_prerequisite=False
# DEBUG:row_match_recognize.src.matcher.matcher:  Assigned row 3 to variable B
# DEBUG:row_match_recognize.src.matcher.matcher:No match found starting at index 3
# INFO:row_match_recognize.src.matcher.matcher:Find matches completed in 0.044266 seconds
# DEBUG:row_match_recognize.src.matcher.row_context:Built indices: 0 row mappings, 0 subset mappings
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'CLASSIFIER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'CLASSIFIER()': <re.Match object; span=(0, 11), match='CLASSIFIER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: CLASSIFIER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function CLASSIFIER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: CLASSIFIER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: CLASSIFIER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: B (type: <class 'str'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting pattern_var to B from evaluator
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Enhanced evaluate called with expr: 'MATCH_NUMBER()', semantics: 'FINAL'
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Pattern match result for 'MATCH_NUMBER()': <re.Match object; span=(0, 13), match='MATCH_NUMBER('>
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Matched function: MATCH_NUMBER, semantics_prefix: None
# DEBUG:row_match_recognize.src.matcher.production_aggregates:Function MATCH_NUMBER not in standard aggregates, using original evaluator
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Falling back to original evaluator for: MATCH_NUMBER()
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Evaluating expression: MATCH_NUMBER() with FINAL semantics
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Context variables: {'A': [1], 'B': [2]}
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Number of rows: 16
# Test PERMUTE - Should match both orderings of A and B
# Pattern value: 'PERMUTE(A, B)'
# Pattern value: 'PERMUTE(A, B)'
# DEBUG: DFA metadata keys: ['has_permute', 'permute_variables', 'permute_structure', 'original_nfa_states', 'original_nfa_transitions', 'construction_method', 'exponential_protection', 'optimization_features', 'build_stats', 'dfa_construction_time', 'cache_hit_rate', 'construction_efficiency', 'optimized', 'optimization_time', 'original_state_count', 'optimized_state_count', 'original_transition_count', 'optimized_transition_count', 'optimization_savings']
# DEBUG: has_permute: True
# DEBUG: has_alternations: False
# DEBUG: No alternation_combinations in DFA metadata
# DEBUG: Parsed alternation_order: {}
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [('B', 3, False)], 'prerequisite': [], 'simple': [], 'dependent': []}
# DEBUG: Processing category 'accepting' with 1 transitions
# DEBUG: Selected accepting transition: B -> state 3 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['A']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('A', 1, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: A -> state 1 (alternation priority: N/A)
# DEBUG: _find_single_match called with start_idx=0
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 0 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 1 with value N/A
# DEBUG: _find_single_match called with start_idx=1
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 1 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 2 with value N/A
# DEBUG: _find_single_match called with start_idx=2
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 2 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG: Processing row 3 with value N/A
# DEBUG: _find_single_match called with start_idx=3
# DEBUG: has_permute_alternations: False
# DEBUG: _needs_backtracking returned: False
# DEBUG: has_complex_back_references: False
# DEBUG: Processing row 3 with value N/A
# DEBUG: Found 1 valid transitions: ['B']
# DEBUG: Categorized transitions: {'accepting': [], 'prerequisite': [], 'simple': [('B', 2, False)], 'dependent': []}
# DEBUG: Processing category 'simple' with 1 transitions
# DEBUG: Selected simple transition: B -> state 2 (alternation priority: N/A)
# DEBUG:row_match_recognize.src.matcher.measure_evaluator:Current index: 2
# INFO:row_match_recognize.src.matcher.production_aggregates:ENHANCED_EVAL_DEBUG: Original evaluator returned: 1 (type: <class 'int'>)
# DEBUG:row_match_recognize.src.executor.match_recognize:Setting match_num to 1 from evaluator
# DEBUG:row_match_recognize.src.executor.match_recognize:ONE ROW PER MATCH with SELECT * - PARTITION BY: ['department'], ORDER BY: ['hire_date'], MEASURES: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:SELECT * - SQL:2016 column ordering: ['department', 'hire_date', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Available columns in result_df: ['salary', 'id', 'region', 'hire_date', 'department', 'name', 'pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Measures: ['pattern_var', 'match_num']
# DEBUG:row_match_recognize.src.executor.match_recognize:Rows per match mode: RowsPerMatch.ONE_ROW
# INFO:row_match_recognize.src.executor.match_recognize:Query execution metrics: {'parsing_time': 0.008706808090209961, 'automata_build_time': 0.0008714199066162109, 'matching_time': 0.18918824195861816, 'result_processing_time': 0.006805896759033203, 'total_time': 0.20688462257385254, 'partition_count': 4, 'match_count': 1}
# INFO:row_match_recognize.src.executor.match_recognize:Pattern cache statistics: {'total_hits': 17, 'total_misses': 21, 'total_compilation_time_saved': 0.4677011966705322, 'memory_used_mb': 10.5}
# INFO:row_match_recognize.src.executor.match_recognize:Cache hit rate: 44.7% (17/38)
# INFO:row_match_recognize.src.executor.match_recognize:Compilation time saved: 0.468s
# INFO:row_match_recognize.src.executor.match_recognize:Cache memory usage: 10.50 MB
#   department   hire_date pattern_var  match_num
# 0      Sales  2021-01-02           B          1
